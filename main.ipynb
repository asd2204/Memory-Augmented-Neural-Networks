# %%
# !pip install tensorflow
# !pip install pandas
# !pip install matplotlib
# !pip install scikit-image

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from .Utility.extend_children import extend_children
from .Utility.extend_generation import extend_generation
from .Utility.load_image import load_image
from .Utility.shuffle_xy import shuffle_xy
from .Utility.one_hot import one_hot
import os
from matplotlib.pyplot import imread
from skimage.transform import resize
#from scipy.misc import imread,imresize

# %%
width = 20

# gather data paths
subfolds = ut.extend_children('data','')
datafolds = [subfolds[1]]
alphabets = ut.extend_generation(datafolds,'')
charpaths = ut.extend_generation(alphabets,'')
chars_dataset = [v.split('/')[2]+'/'+v.split('/')[3] for v in charpaths]
#print(chars_dataset)
# index-value conversion dictionaries for character set
i2v = {i:v for i, v in enumerate(chars_dataset)}
v2i = {v:i for i, v in enumerate(chars_dataset)}

# get size of dataset
mc_dataset = len(charpaths)
print(mc_dataset,'total character classes')

# train split
mc_train = 764
chars_train = chars_dataset[:mc_train]
classes_train = [v2i[v] for v in chars_train]

# validation split
mc_val = mc_dataset-mc_train
chars_val = chars_dataset[-mc_val:]
classes_val = [v2i[v] for v in chars_val]

print('%s characters assigned for training, %s characters assigned for validation'%(mc_train,mc_val))
# Out:
# 964 total character classes
# 764 characters assigned for training, 200 characters assigned for validation

# %%
# load images from character paths
imgs_dataset = []
for i, charfold in enumerate(charpaths):
    if i%200==0:
        #print(charfold)
        print('%s/%s character folders loaded'%(i,mc_dataset))
    imgs_dataset.append([ ut.load_image(imgpath,(width,width))/127.5-1 for imgpath in ut.extend_children(charfold,'.png') ] )
    # access imgs_dataset [ character index ] [ sample index ] [ row,col ]

# split images between train and validation sets
imgs_train = imgs_dataset[:mc_train]
imgs_val = imgs_dataset[-mc_val:]
# Out:
# 0/964 character folders loaded
# 200/964 character folders loaded
# 400/964 character folders loaded
# 600/964 character folders loaded
# 800/964 character folders loaded

# %%
#classes_val, imgs_val = ut.shuffle_xy(classes_val,imgs_val,7)

n_classes = 5
memory_size = 128 # number of features per entry
memory_dim = 40 # number of entries in memory
learning_rate = 1e-3
batch_size = 9

n_inputs = width*width+n_classes
n_hnodes = 200
n_outputs = n_classes
mem_size = memory_size
mem_dim = memory_dim


weights = lambda shape,name: tf.Variable(tf.truncated_normal(shape, stddev=0.1),name=name)
biases = lambda shape,name: tf.Variable(tf.constant(0.1, shape=shape),name=name)
conv2d = lambda x, W: tf.nn.conv2d(x, W, strides=[1, 2, 2, 1], padding='SAME')
max_pool = lambda x: tf.nn.max_pool(x, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')

# %%
import tensorflow as tf
from MANN import MANN

tf.compat.v1.disable_eager_execution()

X = tf.compat.v1.placeholder(tf.float32, shape=[batch_size, None, width, width])
y = tf.compat.v1.placeholder(tf.float32, shape=[batch_size, None, n_classes])

X_mat = tf.transpose(tf.reshape(X,[batch_size,-1,width*width]),perm=[1,0,2])
y_tr = tf.transpose(y,perm=[1,0,2])
y_tm1 = tf.concat([tf.zeros([1,batch_size,n_classes]),y_tr[:-1,:]],0)

X_mann = tf.concat([X_mat,y_tm1],-1)

MANN1 = MANN(n_inputs,n_hnodes,n_classes,memory_size,memory_dim,X_mann,batch_size)

# %%
n_xh = n_inputs+n_hnodes
n_hr = n_hnodes+mem_dim
W_init = tf.compat.v1.keras.initializers.VarianceScaling()
b_init = tf.constant_initializer(0)
#with tf.variable_scope('Weights', reuse=True):

#thetas = [W_gf,b_gf,W_gi,b_gi,W_go,b_go,W_u,b_u,W_kr,b_kr,W_kw,alpha,b_kw,W_o,b_o]

# %%
M, h, c, wu, wr, r, o = MANN1

xentropy = tf.nn.softmax_cross_entropy_with_logits(labels=y_tr,logits=o)
loss = tf.reduce_mean(xentropy)

trainable_variables = tf.compat.v1.trainable_variables()
optimizer = tf.compat.v1.train.AdamOptimizer(learning_rate)
grads, _ = tf.clip_by_global_norm(tf.gradients(loss,trainable_variables),30)
train_step = optimizer.apply_gradients(zip(grads,trainable_variables))

correct_prediction = tf.equal(tf.argmax(o, -1), tf.argmax(y_tr, -1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# %%
sess = tf.compat.v1.Session()
sess.run(tf.compat.v1.global_variables_initializer())
saver = tf.compat.v1.train.Saver()
savedir = './saved_models_omniglot/Mod1/'

# %%
import time
import os

n_epochs = 400
loss_plot, accuracy_plot = [], []
loss_plot2, accuracy_plot2 = [], []
if True:
    saver.restore(sess, os.path.join(savedir,'400/Model.ckpt'))

with sess.as_default():
    for epoch in range(n_epochs):
        print('Epoch {} starting..'.format(epoch+1))
        epoch_start = time.time()
        classes_epoch, imgs_epoch = ut.shuffle_xy(classes_train,imgs_train)
        lo = 10000
        ac = 0
        n_batches = len(classes_epoch)//(n_classes*batch_size)
        for batch in range(n_batches):
            classes_batch = classes_epoch[batch*n_classes*batch_size:(batch+1)*n_classes*batch_size]
            imgs_batch = imgs_epoch[batch*n_classes*batch_size:(batch+1)*n_classes*batch_size]
            
            Xl_batch, yl_batch = [], []
            for episode in range(batch_size):
                imgs_ep = imgs_batch[episode*n_classes:(episode+1)*n_classes]
                Xl_ep, yl_ep = [], []
                for ind, cat in enumerate(imgs_ep):
                    for arr in cat:
                        Xl_ep.append(arr)
                        yl_ep.append(ut.one_hot(ind,n_classes))
                Xl_shuff, yl_shuff = ut.shuffle_xy(Xl_ep,yl_ep)
                X_arr, y_arr = np.asarray(Xl_shuff), np.asarray(yl_shuff)
                Xl_batch.append(X_arr)
                yl_batch.append(y_arr)
            X_train, y_train = np.asarray(Xl_batch), np.asarray(yl_batch)

            _, loss_train, accuracy_train = sess.run((train_step,loss,accuracy),feed_dict={X:X_train,y:y_train})
            if lo>loss_train:
              lo = loss_train
            if ac<accuracy_train:
              ac = accuracy_train
            print('Epoch %d'%(epoch+1),'/ Batch (%d/%d)'%(batch+1,n_batches),'/ Accuracy %.4f / Loss %f'%(accuracy_train,loss_train))
        loss_plot.append(loss_train)
        accuracy_plot.append(accuracy_train)
        loss_plot2.append(lo)
        accuracy_plot2.append(ac)
            
        epoch_end = time.time()
        time_elapsed = epoch_end-epoch_start
        print('Epoch {} complete,'.format(epoch+1),time_elapsed,'seconds elapsed')
        if (epoch+1)%50 == 0:
            iterdir = os.path.join(savedir,str(epoch+1))
            if not os.path.exists(iterdir):
                os.makedirs(iterdir)
            saver.save(sess,'{}/Model.ckpt'.format(iterdir))
        print()
# Out:
# INFO:tensorflow:Restoring parameters from ./saved_models_omniglot/Mod1/400/Model.ckpt
# Epoch 1 starting..
# Epoch 1 / Batch (1/9) / Accuracy 0.2750 / Loss 1.556647
# Epoch 1 / Batch (2/9) / Accuracy 0.2606 / Loss 1.561239
# Epoch 1 / Batch (3/9) / Accuracy 0.2681 / Loss 1.562886
# Epoch 1 / Batch (4/9) / Accuracy 0.2738 / Loss 1.556728
# Epoch 1 / Batch (5/9) / Accuracy 0.2800 / Loss 1.555311
# Epoch 1 / Batch (6/9) / Accuracy 0.2794 / Loss 1.559687
# Epoch 1 / Batch (7/9) / Accuracy 0.2775 / Loss 1.551844
# Epoch 1 / Batch (8/9) / Accuracy 0.2788 / Loss 1.555108
# Epoch 1 / Batch (9/9) / Accuracy 0.2706 / Loss 1.553957
# Epoch 1 complete, 2.5610480308532715 seconds elapsed
#
# Epoch 2 starting..
# Epoch 2 / Batch (1/9) / Accuracy 0.2806 / Loss 1.551204
# Epoch 2 / Batch (2/9) / Accuracy 0.2719 / Loss 1.550385
# Epoch 2 / Batch (3/9) / Accuracy 0.2713 / Loss 1.552791
# Epoch 2 / Batch (4/9) / Accuracy 0.2612 / Loss 1.568821
# Epoch 2 / Batch (5/9) / Accuracy 0.2631 / Loss 1.564814
# Epoch 2 / Batch (6/9) / Accuracy 0.2644 / Loss 1.554205
# Epoch 2 / Batch (7/9) / Accuracy 0.2594 / Loss 1.562756
# Epoch 2 / Batch (8/9) / Accuracy 0.2881 / Loss 1.551256
# Epoch 2 / Batch (9/9) / Accuracy 0.2725 / Loss 1.546915
# Epoch 2 complete, 2.4057846069335938 seconds elapsed
#
# Epoch 3 starting..
# Epoch 3 / Batch (1/9) / Accuracy 0.2675 / Loss 1.556199
# Epoch 3 / Batch (2/9) / Accuracy 0.2625 / Loss 1.557280
# Epoch 3 / Batch (3/9) / Accuracy 0.2756 / Loss 1.550156
# Epoch 3 / Batch (4/9) / Accuracy 0.2650 / Loss 1.552988
# Epoch 3 / Batch (5/9) / Accuracy 0.2812 / Loss 1.546497
# Epoch 3 / Batch (6/9) / Accuracy 0.2706 / Loss 1.553666
# Epoch 3 / Batch (7/9) / Accuracy 0.2656 / Loss 1.551762
# Epoch 3 / Batch (8/9) / Accuracy 0.2825 / Loss 1.547076
# Epoch 3 / Batch (9/9) / Accuracy 0.2750 / Loss 1.546687
# Epoch 3 complete, 2.3972623348236084 seconds elapsed
#
# Epoch 4 starting..
# Epoch 4 / Batch (1/9) / Accuracy 0.2763 / Loss 1.548076
# Epoch 4 / Batch (2/9) / Accuracy 0.2862 / Loss 1.545852
# Epoch 4 / Batch (3/9) / Accuracy 0.2731 / Loss 1.547344
# Epoch 4 / Batch (4/9) / Accuracy 0.2988 / Loss 1.544449
# Epoch 4 / Batch (5/9) / Accuracy 0.2725 / Loss 1.548264
# Epoch 4 / Batch (6/9) / Accuracy 0.2906 / Loss 1.542978
# Epoch 4 / Batch (7/9) / Accuracy 0.2769 / Loss 1.544511
# Epoch 4 / Batch (8/9) / Accuracy 0.2825 / Loss 1.539983
# Epoch 4 / Batch (9/9) / Accuracy 0.2763 / Loss 1.544490
# Epoch 4 complete, 2.38566255569458 seconds elapsed
#
# Epoch 5 starting..
# Epoch 5 / Batch (1/9) / Accuracy 0.2812 / Loss 1.548780
# Epoch 5 / Batch (2/9) / Accuracy 0.2631 / Loss 1.552250
# Epoch 5 / Batch (3/9) / Accuracy 0.2694 / Loss 1.567244
# Epoch 5 / Batch (4/9) / Accuracy 0.2775 / Loss 1.556442
# Epoch 5 / Batch (5/9) / Accuracy 0.2569 / Loss 1.561025
# Epoch 5 / Batch (6/9) / Accuracy 0.2669 / Loss 1.564961
# Epoch 5 / Batch (7/9) / Accuracy 0.2675 / Loss 1.550724
# Epoch 5 / Batch (8/9) / Accuracy 0.2587 / Loss 1.567733
# Epoch 5 / Batch (9/9) / Accuracy 0.2731 / Loss 1.551109
# Epoch 5 complete, 2.382061719894409 seconds elapsed
#
# Epoch 6 starting..
# Epoch 6 / Batch (1/9) / Accuracy 0.2625 / Loss 1.558167
# Epoch 6 / Batch (2/9) / Accuracy 0.2769 / Loss 1.549370
# Epoch 6 / Batch (3/9) / Accuracy 0.2812 / Loss 1.555449
# Epoch 6 / Batch (4/9) / Accuracy 0.2619 / Loss 1.558408
# Epoch 6 / Batch (5/9) / Accuracy 0.2887 / Loss 1.547024
# Epoch 6 / Batch (6/9) / Accuracy 0.2719 / Loss 1.549375
# Epoch 6 / Batch (7/9) / Accuracy 0.2725 / Loss 1.544658
# Epoch 6 / Batch (8/9) / Accuracy 0.2794 / Loss 1.548883
# Epoch 6 / Batch (9/9) / Accuracy 0.2738 / Loss 1.544702
# Epoch 6 complete, 2.427062749862671 seconds elapsed
#
# Epoch 7 starting..
# Epoch 7 / Batch (1/9) / Accuracy 0.2894 / Loss 1.545455
# Epoch 7 / Batch (2/9) / Accuracy 0.2713 / Loss 1.547969
# Epoch 7 / Batch (3/9) / Accuracy 0.2612 / Loss 1.558691
# Epoch 7 / Batch (4/9) / Accuracy 0.2769 / Loss 1.542206
# Epoch 7 / Batch (5/9) / Accuracy 0.2637 / Loss 1.555812
# Epoch 7 / Batch (6/9) / Accuracy 0.2600 / Loss 1.558626
# Epoch 7 / Batch (7/9) / Accuracy 0.2700 / Loss 1.546344
# Epoch 7 / Batch (8/9) / Accuracy 0.2681 / Loss 1.556670
# Epoch 7 / Batch (9/9) / Accuracy 0.2744 / Loss 1.542289
# Epoch 7 complete, 2.424513578414917 seconds elapsed
#
# Epoch 8 starting..
# Epoch 8 / Batch (1/9) / Accuracy 0.2600 / Loss 1.555200
# Epoch 8 / Batch (2/9) / Accuracy 0.2725 / Loss 1.545733
# Epoch 8 / Batch (3/9) / Accuracy 0.2569 / Loss 1.555245
# Epoch 8 / Batch (4/9) / Accuracy 0.2694 / Loss 1.550594
# Epoch 8 / Batch (5/9) / Accuracy 0.2763 / Loss 1.553575
# Epoch 8 / Batch (6/9) / Accuracy 0.2825 / Loss 1.550002
# Epoch 8 / Batch (7/9) / Accuracy 0.2656 / Loss 1.555059
# Epoch 8 / Batch (8/9) / Accuracy 0.2781 / Loss 1.544586
# Epoch 8 / Batch (9/9) / Accuracy 0.2875 / Loss 1.544370
# Epoch 8 complete, 2.4203951358795166 seconds elapsed
#
# Epoch 9 starting..
# Epoch 9 / Batch (1/9) / Accuracy 0.2812 / Loss 1.543235
# Epoch 9 / Batch (2/9) / Accuracy 0.2750 / Loss 1.541922
# Epoch 9 / Batch (3/9) / Accuracy 0.2700 / Loss 1.552112
# Epoch 9 / Batch (4/9) / Accuracy 0.2731 / Loss 1.546657
# Epoch 9 / Batch (5/9) / Accuracy 0.2656 / Loss 1.547779
# Epoch 9 / Batch (6/9) / Accuracy 0.2825 / Loss 1.545973
# Epoch 9 / Batch (7/9) / Accuracy 0.2750 / Loss 1.542777
# Epoch 9 / Batch (8/9) / Accuracy 0.2675 / Loss 1.543586
# Epoch 9 / Batch (9/9) / Accuracy 0.2750 / Loss 1.553763
# Epoch 9 complete, 2.4392507076263428 seconds elapsed
#
# Epoch 10 starting..
# Epoch 10 / Batch (1/9) / Accuracy 0.2856 / Loss 1.544758
# Epoch 10 / Batch (2/9) / Accuracy 0.2819 / Loss 1.546168
# Epoch 10 / Batch (3/9) / Accuracy 0.2825 / Loss 1.547846
# Epoch 10 / Batch (4/9) / Accuracy 0.2756 / Loss 1.551856
# Epoch 10 / Batch (5/9) / Accuracy 0.2694 / Loss 1.560207
# Epoch 10 / Batch (6/9) / Accuracy 0.2669 / Loss 1.549039
# Epoch 10 / Batch (7/9) / Accuracy 0.2500 / Loss 1.579260
# Epoch 10 / Batch (8/9) / Accuracy 0.2738 / Loss 1.549663
# Epoch 10 / Batch (9/9) / Accuracy 0.2669 / Loss 1.551029
# Epoch 10 complete, 2.4163811206817627 seconds elapsed
#
# Epoch 11 starting..
# Epoch 11 / Batch (1/9) / Accuracy 0.2612 / Loss 1.557975
# Epoch 11 / Batch (2/9) / Accuracy 0.2612 / Loss 1.556224
# Epoch 11 / Batch (3/9) / Accuracy 0.2663 / Loss 1.555637
# Epoch 11 / Batch (4/9) / Accuracy 0.2619 / Loss 1.559867
# Epoch 11 / Batch (5/9) / Accuracy 0.2825 / Loss 1.548911
# Epoch 11 / Batch (6/9) / Accuracy 0.2775 / Loss 1.551898
# Epoch 11 / Batch (7/9) / Accuracy 0.2837 / Loss 1.546722
# Epoch 11 / Batch (8/9) / Accuracy 0.2800 / Loss 1.553620
# Epoch 11 / Batch (9/9) / Accuracy 0.2619 / Loss 1.550895
# Epoch 11 complete, 2.4412620067596436 seconds elapsed
#
# Epoch 12 starting..
# Epoch 12 / Batch (1/9) / Accuracy 0.2681 / Loss 1.546464
# Epoch 12 / Batch (2/9) / Accuracy 0.2869 / Loss 1.552200
# Epoch 12 / Batch (3/9) / Accuracy 0.2788 / Loss 1.545984
# Epoch 12 / Batch (4/9) / Accuracy 0.2606 / Loss 1.554335
# Epoch 12 / Batch (5/9) / Accuracy 0.2600 / Loss 1.562540
# Epoch 12 / Batch (6/9) / Accuracy 0.2844 / Loss 1.549306
# Epoch 12 / Batch (7/9) / Accuracy 0.2644 / Loss 1.552151
# Epoch 12 / Batch (8/9) / Accuracy 0.2769 / Loss 1.548428
# Epoch 12 / Batch (9/9) / Accuracy 0.2763 / Loss 1.547508
# Epoch 12 complete, 2.4346938133239746 seconds elapsed
#
# Epoch 13 starting..
# Epoch 13 / Batch (1/9) / Accuracy 0.2875 / Loss 1.546210
# Epoch 13 / Batch (2/9) / Accuracy 0.2756 / Loss 1.549404
# Epoch 13 / Batch (3/9) / Accuracy 0.2631 / Loss 1.545804
# Epoch 13 / Batch (4/9) / Accuracy 0.2681 / Loss 1.548580
# Epoch 13 / Batch (5/9) / Accuracy 0.2756 / Loss 1.547615
# Epoch 13 / Batch (6/9) / Accuracy 0.2750 / Loss 1.546796
# Epoch 13 / Batch (7/9) / Accuracy 0.2837 / Loss 1.544133
# Epoch 13 / Batch (8/9) / Accuracy 0.2694 / Loss 1.546000
# Epoch 13 / Batch (9/9) / Accuracy 0.2750 / Loss 1.545341
# Epoch 13 complete, 2.4222006797790527 seconds elapsed
#
# Epoch 14 starting..
# Epoch 14 / Batch (1/9) / Accuracy 0.2681 / Loss 1.549595
# Epoch 14 / Batch (2/9) / Accuracy 0.2856 / Loss 1.556998
# Epoch 14 / Batch (3/9) / Accuracy 0.2681 / Loss 1.550745
# Epoch 14 / Batch (4/9) / Accuracy 0.2750 / Loss 1.569789
# Epoch 14 / Batch (5/9) / Accuracy 0.2719 / Loss 1.557242
# Epoch 14 / Batch (6/9) / Accuracy 0.2781 / Loss 1.547238
# Epoch 14 / Batch (7/9) / Accuracy 0.2906 / Loss 1.551792
# Epoch 14 / Batch (8/9) / Accuracy 0.2912 / Loss 1.542654
# Epoch 14 / Batch (9/9) / Accuracy 0.2713 / Loss 1.553490
# Epoch 14 complete, 2.4211764335632324 seconds elapsed
#
# Epoch 15 starting..
# Epoch 15 / Batch (1/9) / Accuracy 0.2575 / Loss 1.551259
# Epoch 15 / Batch (2/9) / Accuracy 0.2525 / Loss 1.553505
# Epoch 15 / Batch (3/9) / Accuracy 0.2750 / Loss 1.550885
# Epoch 15 / Batch (4/9) / Accuracy 0.2731 / Loss 1.550185
# Epoch 15 / Batch (5/9) / Accuracy 0.2738 / Loss 1.546812
# Epoch 15 / Batch (6/9) / Accuracy 0.2706 / Loss 1.548874
# Epoch 15 / Batch (7/9) / Accuracy 0.2625 / Loss 1.551788
# Epoch 15 / Batch (8/9) / Accuracy 0.2550 / Loss 1.552671
# Epoch 15 / Batch (9/9) / Accuracy 0.2800 / Loss 1.545991
# Epoch 15 complete, 2.4404218196868896 seconds elapsed
#
# Epoch 16 starting..
# Epoch 16 / Batch (1/9) / Accuracy 0.2675 / Loss 1.553702
# Epoch 16 / Batch (2/9) / Accuracy 0.2650 / Loss 1.553657
# Epoch 16 / Batch (3/9) / Accuracy 0.2606 / Loss 1.554623
# Epoch 16 / Batch (4/9) / Accuracy 0.2719 / Loss 1.548458
# Epoch 16 / Batch (5/9) / Accuracy 0.2781 / Loss 1.551073
# Epoch 16 / Batch (6/9) / Accuracy 0.2819 / Loss 1.546565
# Epoch 16 / Batch (7/9) / Accuracy 0.2781 / Loss 1.549484
# Epoch 16 / Batch (8/9) / Accuracy 0.2562 / Loss 1.549333
# Epoch 16 / Batch (9/9) / Accuracy 0.2637 / Loss 1.548276
# Epoch 16 complete, 2.4857847690582275 seconds elapsed
#
# Epoch 17 starting..
# Epoch 17 / Batch (1/9) / Accuracy 0.2837 / Loss 1.547186
# Epoch 17 / Batch (2/9) / Accuracy 0.2706 / Loss 1.551096
# Epoch 17 / Batch (3/9) / Accuracy 0.2575 / Loss 1.549613
# Epoch 17 / Batch (4/9) / Accuracy 0.2688 / Loss 1.547889
# Epoch 17 / Batch (5/9) / Accuracy 0.2794 / Loss 1.546367
# Epoch 17 / Batch (6/9) / Accuracy 0.2794 / Loss 1.541805
# Epoch 17 / Batch (7/9) / Accuracy 0.2844 / Loss 1.545986
# Epoch 17 / Batch (8/9) / Accuracy 0.2881 / Loss 1.547451
# Epoch 17 / Batch (9/9) / Accuracy 0.2644 / Loss 1.551584
# Epoch 17 complete, 2.4102494716644287 seconds elapsed
#
# Epoch 18 starting..
# Epoch 18 / Batch (1/9) / Accuracy 0.2812 / Loss 1.549983
# Epoch 18 / Batch (2/9) / Accuracy 0.2794 / Loss 1.542161
# Epoch 18 / Batch (3/9) / Accuracy 0.2706 / Loss 1.553272
# Epoch 18 / Batch (4/9) / Accuracy 0.2925 / Loss 1.546629
# Epoch 18 / Batch (5/9) / Accuracy 0.2663 / Loss 1.547555
# Epoch 18 / Batch (6/9) / Accuracy 0.2912 / Loss 1.548248
# Epoch 18 / Batch (7/9) / Accuracy 0.2819 / Loss 1.539762
# Epoch 18 / Batch (8/9) / Accuracy 0.2738 / Loss 1.549254
# Epoch 18 / Batch (9/9) / Accuracy 0.2606 / Loss 1.558175
# Epoch 18 complete, 2.464838981628418 seconds elapsed
#
# Epoch 19 starting..
# Epoch 19 / Batch (1/9) / Accuracy 0.2844 / Loss 1.544847
# Epoch 19 / Batch (2/9) / Accuracy 0.2531 / Loss 1.557200
# Epoch 19 / Batch (3/9) / Accuracy 0.2725 / Loss 1.580580
# Epoch 19 / Batch (4/9) / Accuracy 0.2650 / Loss 1.559574
# Epoch 19 / Batch (5/9) / Accuracy 0.2719 / Loss 1.577079
# Epoch 19 / Batch (6/9) / Accuracy 0.2656 / Loss 1.560402
# Epoch 19 / Batch (7/9) / Accuracy 0.2663 / Loss 1.561903
# Epoch 19 / Batch (8/9) / Accuracy 0.2656 / Loss 1.563652
# Epoch 19 / Batch (9/9) / Accuracy 0.2788 / Loss 1.552996
# Epoch 19 complete, 2.4367482662200928 seconds elapsed
#
# Epoch 20 starting..
# Epoch 20 / Batch (1/9) / Accuracy 0.2806 / Loss 1.562828
# Epoch 20 / Batch (2/9) / Accuracy 0.2738 / Loss 1.556577
# Epoch 20 / Batch (3/9) / Accuracy 0.2781 / Loss 1.555697
# Epoch 20 / Batch (4/9) / Accuracy 0.2694 / Loss 1.554495
# Epoch 20 / Batch (5/9) / Accuracy 0.2825 / Loss 1.547713
# Epoch 20 / Batch (6/9) / Accuracy 0.2744 / Loss 1.555232
# Epoch 20 / Batch (7/9) / Accuracy 0.2800 / Loss 1.552097
# Epoch 20 / Batch (8/9) / Accuracy 0.2831 / Loss 1.555160
# Epoch 20 / Batch (9/9) / Accuracy 0.2688 / Loss 1.549746
# Epoch 20 complete, 2.429497480392456 seconds elapsed
#
# Epoch 21 starting..
# Epoch 21 / Batch (1/9) / Accuracy 0.2656 / Loss 1.555063
# Epoch 21 / Batch (2/9) / Accuracy 0.2800 / Loss 1.551029
# Epoch 21 / Batch (3/9) / Accuracy 0.2819 / Loss 1.545697
# Epoch 21 / Batch (4/9) / Accuracy 0.2713 / Loss 1.553406
# Epoch 21 / Batch (5/9) / Accuracy 0.2494 / Loss 1.560367
# Epoch 21 / Batch (6/9) / Accuracy 0.2881 / Loss 1.556352
# Epoch 21 / Batch (7/9) / Accuracy 0.2725 / Loss 1.546715
# Epoch 21 / Batch (8/9) / Accuracy 0.2681 / Loss 1.556291
# Epoch 21 / Batch (9/9) / Accuracy 0.2637 / Loss 1.558273
# Epoch 21 complete, 2.445901393890381 seconds elapsed
#
# Epoch 22 starting..
# Epoch 22 / Batch (1/9) / Accuracy 0.2650 / Loss 1.551914
# Epoch 22 / Batch (2/9) / Accuracy 0.2756 / Loss 1.552522
# Epoch 22 / Batch (3/9) / Accuracy 0.2706 / Loss 1.556687
# Epoch 22 / Batch (4/9) / Accuracy 0.2644 / Loss 1.557046
# Epoch 22 / Batch (5/9) / Accuracy 0.2831 / Loss 1.542807
# Epoch 22 / Batch (6/9) / Accuracy 0.2844 / Loss 1.550572
# Epoch 22 / Batch (7/9) / Accuracy 0.2681 / Loss 1.548768
# Epoch 22 / Batch (8/9) / Accuracy 0.2625 / Loss 1.546784
# Epoch 22 / Batch (9/9) / Accuracy 0.2875 / Loss 1.552159
# Epoch 22 complete, 2.429072380065918 seconds elapsed
#
# Epoch 23 starting..
# Epoch 23 / Batch (1/9) / Accuracy 0.2756 / Loss 1.544584
# Epoch 23 / Batch (2/9) / Accuracy 0.2756 / Loss 1.551060
# Epoch 23 / Batch (3/9) / Accuracy 0.2806 / Loss 1.546434
# Epoch 23 / Batch (4/9) / Accuracy 0.2744 / Loss 1.554602
# Epoch 23 / Batch (5/9) / Accuracy 0.2725 / Loss 1.557484
# Epoch 23 / Batch (6/9) / Accuracy 0.2525 / Loss 1.573944
# Epoch 23 / Batch (7/9) / Accuracy 0.2750 / Loss 1.552246
# Epoch 23 / Batch (8/9) / Accuracy 0.2594 / Loss 1.566139
# Epoch 23 / Batch (9/9) / Accuracy 0.2738 / Loss 1.546666
# Epoch 23 complete, 2.3936707973480225 seconds elapsed
#
# Epoch 24 starting..
# Epoch 24 / Batch (1/9) / Accuracy 0.2812 / Loss 1.551394
# Epoch 24 / Batch (2/9) / Accuracy 0.2644 / Loss 1.562289
# Epoch 24 / Batch (3/9) / Accuracy 0.2706 / Loss 1.549729
# Epoch 24 / Batch (4/9) / Accuracy 0.2769 / Loss 1.555831
# Epoch 24 / Batch (5/9) / Accuracy 0.2569 / Loss 1.550794
# Epoch 24 / Batch (6/9) / Accuracy 0.2825 / Loss 1.546696
# Epoch 24 / Batch (7/9) / Accuracy 0.2681 / Loss 1.551135
# Epoch 24 / Batch (8/9) / Accuracy 0.2625 / Loss 1.548239
# Epoch 24 / Batch (9/9) / Accuracy 0.2788 / Loss 1.549120
# Epoch 24 complete, 2.4190003871917725 seconds elapsed
#
# Epoch 25 starting..
# Epoch 25 / Batch (1/9) / Accuracy 0.2738 / Loss 1.547858
# Epoch 25 / Batch (2/9) / Accuracy 0.2738 / Loss 1.550082
# Epoch 25 / Batch (3/9) / Accuracy 0.2694 / Loss 1.548480
# Epoch 25 / Batch (4/9) / Accuracy 0.2569 / Loss 1.551041
# Epoch 25 / Batch (5/9) / Accuracy 0.2713 / Loss 1.550114
# Epoch 25 / Batch (6/9) / Accuracy 0.2725 / Loss 1.563966
# Epoch 25 / Batch (7/9) / Accuracy 0.2694 / Loss 1.551098
# Epoch 25 / Batch (8/9) / Accuracy 0.2656 / Loss 1.580450
# Epoch 25 / Batch (9/9) / Accuracy 0.2700 / Loss 1.548700
# Epoch 25 complete, 2.45953369140625 seconds elapsed
#
# Epoch 26 starting..
# Epoch 26 / Batch (1/9) / Accuracy 0.2806 / Loss 1.568429
# Epoch 26 / Batch (2/9) / Accuracy 0.2713 / Loss 1.549247
# Epoch 26 / Batch (3/9) / Accuracy 0.2581 / Loss 1.563428
# Epoch 26 / Batch (4/9) / Accuracy 0.2612 / Loss 1.554596
# Epoch 26 / Batch (5/9) / Accuracy 0.2706 / Loss 1.557002
# Epoch 26 / Batch (6/9) / Accuracy 0.2681 / Loss 1.561082
# Epoch 26 / Batch (7/9) / Accuracy 0.2663 / Loss 1.549439
# Epoch 26 / Batch (8/9) / Accuracy 0.2681 / Loss 1.558258
# Epoch 26 / Batch (9/9) / Accuracy 0.2656 / Loss 1.554897
# Epoch 26 complete, 2.4399824142456055 seconds elapsed
#
# Epoch 27 starting..
# Epoch 27 / Batch (1/9) / Accuracy 0.2731 / Loss 1.552018
# Epoch 27 / Batch (2/9) / Accuracy 0.2644 / Loss 1.554065
# Epoch 27 / Batch (3/9) / Accuracy 0.2556 / Loss 1.552497
# Epoch 27 / Batch (4/9) / Accuracy 0.2706 / Loss 1.556157
# Epoch 27 / Batch (5/9) / Accuracy 0.2700 / Loss 1.551586
# Epoch 27 / Batch (6/9) / Accuracy 0.2862 / Loss 1.549230
# Epoch 27 / Batch (7/9) / Accuracy 0.2562 / Loss 1.549098
# Epoch 27 / Batch (8/9) / Accuracy 0.2719 / Loss 1.551356
# Epoch 27 / Batch (9/9) / Accuracy 0.2788 / Loss 1.550233
# Epoch 27 complete, 2.4192543029785156 seconds elapsed
#
# Epoch 28 starting..
# Epoch 28 / Batch (1/9) / Accuracy 0.2744 / Loss 1.546579
# Epoch 28 / Batch (2/9) / Accuracy 0.2544 / Loss 1.561350
# Epoch 28 / Batch (3/9) / Accuracy 0.2587 / Loss 1.557761
# Epoch 28 / Batch (4/9) / Accuracy 0.2756 / Loss 1.550847
# Epoch 28 / Batch (5/9) / Accuracy 0.2456 / Loss 1.562025
# Epoch 28 / Batch (6/9) / Accuracy 0.2719 / Loss 1.547318
# Epoch 28 / Batch (7/9) / Accuracy 0.2681 / Loss 1.549654
# Epoch 28 / Batch (8/9) / Accuracy 0.2862 / Loss 1.548116
# Epoch 28 / Batch (9/9) / Accuracy 0.2625 / Loss 1.552581
# Epoch 28 complete, 2.399209499359131 seconds elapsed
#
# Epoch 29 starting..
# Epoch 29 / Batch (1/9) / Accuracy 0.2681 / Loss 1.551017
# Epoch 29 / Batch (2/9) / Accuracy 0.2656 / Loss 1.552609
# Epoch 29 / Batch (3/9) / Accuracy 0.2763 / Loss 1.547939
# Epoch 29 / Batch (4/9) / Accuracy 0.2756 / Loss 1.549968
# Epoch 29 / Batch (5/9) / Accuracy 0.2887 / Loss 1.542650
# Epoch 29 / Batch (6/9) / Accuracy 0.2706 / Loss 1.547651
# Epoch 29 / Batch (7/9) / Accuracy 0.2637 / Loss 1.545001
# Epoch 29 / Batch (8/9) / Accuracy 0.2631 / Loss 1.546425
# Epoch 29 / Batch (9/9) / Accuracy 0.2644 / Loss 1.546133
# Epoch 29 complete, 2.429075002670288 seconds elapsed
#
# Epoch 30 starting..
# Epoch 30 / Batch (1/9) / Accuracy 0.2962 / Loss 1.541695
# Epoch 30 / Batch (2/9) / Accuracy 0.2681 / Loss 1.549169
# Epoch 30 / Batch (3/9) / Accuracy 0.2644 / Loss 1.546391
# Epoch 30 / Batch (4/9) / Accuracy 0.2800 / Loss 1.555275
# Epoch 30 / Batch (5/9) / Accuracy 0.2706 / Loss 1.543783
# Epoch 30 / Batch (6/9) / Accuracy 0.2756 / Loss 1.549924
# Epoch 30 / Batch (7/9) / Accuracy 0.2694 / Loss 1.555217
# Epoch 30 / Batch (8/9) / Accuracy 0.2700 / Loss 1.552841
# Epoch 30 / Batch (9/9) / Accuracy 0.2619 / Loss 1.557891
# Epoch 30 complete, 2.4308769702911377 seconds elapsed
#
# Epoch 31 starting..
# Epoch 31 / Batch (1/9) / Accuracy 0.2706 / Loss 1.555477
# Epoch 31 / Batch (2/9) / Accuracy 0.2619 / Loss 1.557154
# Epoch 31 / Batch (3/9) / Accuracy 0.2463 / Loss 1.564073
# Epoch 31 / Batch (4/9) / Accuracy 0.2794 / Loss 1.549506
# Epoch 31 / Batch (5/9) / Accuracy 0.2744 / Loss 1.557959
# Epoch 31 / Batch (6/9) / Accuracy 0.2900 / Loss 1.552310
# Epoch 31 / Batch (7/9) / Accuracy 0.2681 / Loss 1.555881
# Epoch 31 / Batch (8/9) / Accuracy 0.2694 / Loss 1.557167
# Epoch 31 / Batch (9/9) / Accuracy 0.2756 / Loss 1.550875
# Epoch 31 complete, 2.405236005783081 seconds elapsed
#
# Epoch 32 starting..
# Epoch 32 / Batch (1/9) / Accuracy 0.2825 / Loss 1.547778
# Epoch 32 / Batch (2/9) / Accuracy 0.2937 / Loss 1.548599
# Epoch 32 / Batch (3/9) / Accuracy 0.2806 / Loss 1.546627
# Epoch 32 / Batch (4/9) / Accuracy 0.2550 / Loss 1.558460
# Epoch 32 / Batch (5/9) / Accuracy 0.2769 / Loss 1.548067
# Epoch 32 / Batch (6/9) / Accuracy 0.2800 / Loss 1.552267
# Epoch 32 / Batch (7/9) / Accuracy 0.2606 / Loss 1.549196
# Epoch 32 / Batch (8/9) / Accuracy 0.2562 / Loss 1.559145
# Epoch 32 / Batch (9/9) / Accuracy 0.2706 / Loss 1.552196
# Epoch 32 complete, 2.4571163654327393 seconds elapsed
#
# Epoch 33 starting..
# Epoch 33 / Batch (1/9) / Accuracy 0.2738 / Loss 1.546422
# Epoch 33 / Batch (2/9) / Accuracy 0.2750 / Loss 1.542725
# Epoch 33 / Batch (3/9) / Accuracy 0.2756 / Loss 1.550812
# Epoch 33 / Batch (4/9) / Accuracy 0.2738 / Loss 1.548155
# Epoch 33 / Batch (5/9) / Accuracy 0.2819 / Loss 1.548648
# Epoch 33 / Batch (6/9) / Accuracy 0.2769 / Loss 1.557273
# Epoch 33 / Batch (7/9) / Accuracy 0.2744 / Loss 1.545799
# Epoch 33 / Batch (8/9) / Accuracy 0.2675 / Loss 1.556337
# Epoch 33 / Batch (9/9) / Accuracy 0.2869 / Loss 1.538948
# Epoch 33 complete, 2.4160306453704834 seconds elapsed
#
# Epoch 34 starting..
# Epoch 34 / Batch (1/9) / Accuracy 0.2600 / Loss 1.556894
# Epoch 34 / Batch (2/9) / Accuracy 0.2688 / Loss 1.548592
# Epoch 34 / Batch (3/9) / Accuracy 0.2644 / Loss 1.560277
# Epoch 34 / Batch (4/9) / Accuracy 0.2719 / Loss 1.557733
# Epoch 34 / Batch (5/9) / Accuracy 0.2750 / Loss 1.551543
# Epoch 34 / Batch (6/9) / Accuracy 0.2637 / Loss 1.550656
# Epoch 34 / Batch (7/9) / Accuracy 0.2694 / Loss 1.558520
# Epoch 34 / Batch (8/9) / Accuracy 0.2844 / Loss 1.549590
# Epoch 34 / Batch (9/9) / Accuracy 0.2856 / Loss 1.552208
# Epoch 34 complete, 2.421488046646118 seconds elapsed
#
# Epoch 35 starting..
# Epoch 35 / Batch (1/9) / Accuracy 0.2788 / Loss 1.549765
# Epoch 35 / Batch (2/9) / Accuracy 0.2681 / Loss 1.547973
# Epoch 35 / Batch (3/9) / Accuracy 0.2663 / Loss 1.554611
# Epoch 35 / Batch (4/9) / Accuracy 0.2781 / Loss 1.545223
# Epoch 35 / Batch (5/9) / Accuracy 0.2688 / Loss 1.554834
# Epoch 35 / Batch (6/9) / Accuracy 0.2794 / Loss 1.544811
# Epoch 35 / Batch (7/9) / Accuracy 0.2688 / Loss 1.550834
# Epoch 35 / Batch (8/9) / Accuracy 0.2962 / Loss 1.546364
# Epoch 35 / Batch (9/9) / Accuracy 0.2656 / Loss 1.547710
# Epoch 35 complete, 2.4114809036254883 seconds elapsed
#
# Epoch 36 starting..
# Epoch 36 / Batch (1/9) / Accuracy 0.2706 / Loss 1.552503
# Epoch 36 / Batch (2/9) / Accuracy 0.2806 / Loss 1.539361
# Epoch 36 / Batch (3/9) / Accuracy 0.2738 / Loss 1.546513
# Epoch 36 / Batch (4/9) / Accuracy 0.2819 / Loss 1.541270
# Epoch 36 / Batch (5/9) / Accuracy 0.2781 / Loss 1.553601
# Epoch 36 / Batch (6/9) / Accuracy 0.2819 / Loss 1.555073
# Epoch 36 / Batch (7/9) / Accuracy 0.2744 / Loss 1.546943
# Epoch 36 / Batch (8/9) / Accuracy 0.2750 / Loss 1.564300
# Epoch 36 / Batch (9/9) / Accuracy 0.2819 / Loss 1.544577
# Epoch 36 complete, 2.399961233139038 seconds elapsed
#
# Epoch 37 starting..
# Epoch 37 / Batch (1/9) / Accuracy 0.2763 / Loss 1.559909
# Epoch 37 / Batch (2/9) / Accuracy 0.2731 / Loss 1.550303
# Epoch 37 / Batch (3/9) / Accuracy 0.2744 / Loss 1.554513
# Epoch 37 / Batch (4/9) / Accuracy 0.2594 / Loss 1.555532
# Epoch 37 / Batch (5/9) / Accuracy 0.2644 / Loss 1.552464
# Epoch 37 / Batch (6/9) / Accuracy 0.2656 / Loss 1.553861
# Epoch 37 / Batch (7/9) / Accuracy 0.2713 / Loss 1.547940
# Epoch 37 / Batch (8/9) / Accuracy 0.2656 / Loss 1.554337
# Epoch 37 / Batch (9/9) / Accuracy 0.2844 / Loss 1.546429
# Epoch 37 complete, 2.4283745288848877 seconds elapsed
#
# Epoch 38 starting..
# Epoch 38 / Batch (1/9) / Accuracy 0.2681 / Loss 1.551063
# Epoch 38 / Batch (2/9) / Accuracy 0.2713 / Loss 1.551109
# Epoch 38 / Batch (3/9) / Accuracy 0.2900 / Loss 1.542794
# Epoch 38 / Batch (4/9) / Accuracy 0.2713 / Loss 1.544247
# Epoch 38 / Batch (5/9) / Accuracy 0.2706 / Loss 1.551187
# Epoch 38 / Batch (6/9) / Accuracy 0.2744 / Loss 1.543430
# Epoch 38 / Batch (7/9) / Accuracy 0.2906 / Loss 1.553437
# Epoch 38 / Batch (8/9) / Accuracy 0.2594 / Loss 1.548167
# Epoch 38 / Batch (9/9) / Accuracy 0.2738 / Loss 1.546291
# Epoch 38 complete, 2.397484302520752 seconds elapsed
#
# Epoch 39 starting..
# Epoch 39 / Batch (1/9) / Accuracy 0.2831 / Loss 1.546375
# Epoch 39 / Batch (2/9) / Accuracy 0.2887 / Loss 1.553573
# Epoch 39 / Batch (3/9) / Accuracy 0.2637 / Loss 1.548772
# Epoch 39 / Batch (4/9) / Accuracy 0.2788 / Loss 1.547485
# Epoch 39 / Batch (5/9) / Accuracy 0.2675 / Loss 1.547854
# Epoch 39 / Batch (6/9) / Accuracy 0.2713 / Loss 1.570039
# Epoch 39 / Batch (7/9) / Accuracy 0.2644 / Loss 1.565608
# Epoch 39 / Batch (8/9) / Accuracy 0.2750 / Loss 1.557721
# Epoch 39 / Batch (9/9) / Accuracy 0.2562 / Loss 1.573087
# Epoch 39 complete, 2.3902759552001953 seconds elapsed
#
# Epoch 40 starting..
# Epoch 40 / Batch (1/9) / Accuracy 0.2819 / Loss 1.557728
# Epoch 40 / Batch (2/9) / Accuracy 0.2612 / Loss 1.566958
# Epoch 40 / Batch (3/9) / Accuracy 0.2519 / Loss 1.568402
# Epoch 40 / Batch (4/9) / Accuracy 0.2819 / Loss 1.556250
# Epoch 40 / Batch (5/9) / Accuracy 0.2594 / Loss 1.564846
# Epoch 40 / Batch (6/9) / Accuracy 0.2725 / Loss 1.549921
# Epoch 40 / Batch (7/9) / Accuracy 0.2775 / Loss 1.554511
# Epoch 40 / Batch (8/9) / Accuracy 0.2631 / Loss 1.562018
# Epoch 40 / Batch (9/9) / Accuracy 0.2806 / Loss 1.547575
# Epoch 40 complete, 2.3930234909057617 seconds elapsed
#
# Epoch 41 starting..
# Epoch 41 / Batch (1/9) / Accuracy 0.2719 / Loss 1.558267
# Epoch 41 / Batch (2/9) / Accuracy 0.2731 / Loss 1.551934
# Epoch 41 / Batch (3/9) / Accuracy 0.2700 / Loss 1.551709
# Epoch 41 / Batch (4/9) / Accuracy 0.2637 / Loss 1.555797
# Epoch 41 / Batch (5/9) / Accuracy 0.2719 / Loss 1.551557
# Epoch 41 / Batch (6/9) / Accuracy 0.2656 / Loss 1.555620
# Epoch 41 / Batch (7/9) / Accuracy 0.2756 / Loss 1.556575
# Epoch 41 / Batch (8/9) / Accuracy 0.2781 / Loss 1.548584
# Epoch 41 / Batch (9/9) / Accuracy 0.2587 / Loss 1.556499
# Epoch 41 complete, 2.4136784076690674 seconds elapsed
#
# Epoch 42 starting..
# Epoch 42 / Batch (1/9) / Accuracy 0.2769 / Loss 1.550896
# Epoch 42 / Batch (2/9) / Accuracy 0.2769 / Loss 1.557245
# Epoch 42 / Batch (3/9) / Accuracy 0.2569 / Loss 1.558447
# Epoch 42 / Batch (4/9) / Accuracy 0.2650 / Loss 1.550433
# Epoch 42 / Batch (5/9) / Accuracy 0.2788 / Loss 1.554023
# Epoch 42 / Batch (6/9) / Accuracy 0.2688 / Loss 1.555199
# Epoch 42 / Batch (7/9) / Accuracy 0.2875 / Loss 1.550702
# Epoch 42 / Batch (8/9) / Accuracy 0.2600 / Loss 1.565260
# Epoch 42 / Batch (9/9) / Accuracy 0.2694 / Loss 1.550247
# Epoch 42 complete, 2.377340078353882 seconds elapsed
#
# Epoch 43 starting..
# Epoch 43 / Batch (1/9) / Accuracy 0.2713 / Loss 1.558406
# Epoch 43 / Batch (2/9) / Accuracy 0.2825 / Loss 1.549254
# Epoch 43 / Batch (3/9) / Accuracy 0.2756 / Loss 1.553553
# Epoch 43 / Batch (4/9) / Accuracy 0.2637 / Loss 1.550477
# Epoch 43 / Batch (5/9) / Accuracy 0.2637 / Loss 1.561123
# Epoch 43 / Batch (6/9) / Accuracy 0.2769 / Loss 1.549112
# Epoch 43 / Batch (7/9) / Accuracy 0.2725 / Loss 1.554691
# Epoch 43 / Batch (8/9) / Accuracy 0.2806 / Loss 1.549097
# Epoch 43 / Batch (9/9) / Accuracy 0.2713 / Loss 1.556485
# Epoch 43 complete, 2.3964922428131104 seconds elapsed
#
# Epoch 44 starting..
# Epoch 44 / Batch (1/9) / Accuracy 0.2763 / Loss 1.554184
# Epoch 44 / Batch (2/9) / Accuracy 0.2706 / Loss 1.550516
# Epoch 44 / Batch (3/9) / Accuracy 0.2763 / Loss 1.566738
# Epoch 44 / Batch (4/9) / Accuracy 0.2862 / Loss 1.549271
# Epoch 44 / Batch (5/9) / Accuracy 0.2681 / Loss 1.567458
# Epoch 44 / Batch (6/9) / Accuracy 0.2738 / Loss 1.551108
# Epoch 44 / Batch (7/9) / Accuracy 0.2713 / Loss 1.565518
# Epoch 44 / Batch (8/9) / Accuracy 0.2650 / Loss 1.556779
# Epoch 44 / Batch (9/9) / Accuracy 0.2562 / Loss 1.572065
# Epoch 44 complete, 2.4015231132507324 seconds elapsed
#
# Epoch 45 starting..
# Epoch 45 / Batch (1/9) / Accuracy 0.2887 / Loss 1.547990
# Epoch 45 / Batch (2/9) / Accuracy 0.2700 / Loss 1.563322
# Epoch 45 / Batch (3/9) / Accuracy 0.2631 / Loss 1.554295
# Epoch 45 / Batch (4/9) / Accuracy 0.2819 / Loss 1.548810
# Epoch 45 / Batch (5/9) / Accuracy 0.2719 / Loss 1.559997
# Epoch 45 / Batch (6/9) / Accuracy 0.2663 / Loss 1.554987
# Epoch 45 / Batch (7/9) / Accuracy 0.2819 / Loss 1.551423
# Epoch 45 / Batch (8/9) / Accuracy 0.2675 / Loss 1.551239
# Epoch 45 / Batch (9/9) / Accuracy 0.2731 / Loss 1.549273
# Epoch 45 complete, 2.4287233352661133 seconds elapsed
#
# Epoch 46 starting..
# Epoch 46 / Batch (1/9) / Accuracy 0.2606 / Loss 1.549988
# Epoch 46 / Batch (2/9) / Accuracy 0.2725 / Loss 1.549647
# Epoch 46 / Batch (3/9) / Accuracy 0.2606 / Loss 1.546311
# Epoch 46 / Batch (4/9) / Accuracy 0.2713 / Loss 1.550523
# Epoch 46 / Batch (5/9) / Accuracy 0.2831 / Loss 1.544088
# Epoch 46 / Batch (6/9) / Accuracy 0.2681 / Loss 1.549801
# Epoch 46 / Batch (7/9) / Accuracy 0.2550 / Loss 1.548515
# Epoch 46 / Batch (8/9) / Accuracy 0.2881 / Loss 1.558946
# Epoch 46 / Batch (9/9) / Accuracy 0.2713 / Loss 1.596070
# Epoch 46 complete, 2.4751687049865723 seconds elapsed
#
# Epoch 47 starting..
# Epoch 47 / Batch (1/9) / Accuracy 0.2769 / Loss 1.567407
# Epoch 47 / Batch (2/9) / Accuracy 0.2469 / Loss 1.581125
# Epoch 47 / Batch (3/9) / Accuracy 0.2637 / Loss 1.550996
# Epoch 47 / Batch (4/9) / Accuracy 0.2844 / Loss 1.569649
# Epoch 47 / Batch (5/9) / Accuracy 0.2612 / Loss 1.566358
# Epoch 47 / Batch (6/9) / Accuracy 0.2694 / Loss 1.555144
# Epoch 47 / Batch (7/9) / Accuracy 0.2819 / Loss 1.555297
# Epoch 47 / Batch (8/9) / Accuracy 0.2769 / Loss 1.559030
# Epoch 47 / Batch (9/9) / Accuracy 0.2550 / Loss 1.554874
# Epoch 47 complete, 2.413492441177368 seconds elapsed
#
# Epoch 48 starting..
# Epoch 48 / Batch (1/9) / Accuracy 0.2769 / Loss 1.557513
# Epoch 48 / Batch (2/9) / Accuracy 0.2719 / Loss 1.560434
# Epoch 48 / Batch (3/9) / Accuracy 0.2744 / Loss 1.557184
# Epoch 48 / Batch (4/9) / Accuracy 0.2556 / Loss 1.555330
# Epoch 48 / Batch (5/9) / Accuracy 0.2700 / Loss 1.558975
# Epoch 48 / Batch (6/9) / Accuracy 0.2919 / Loss 1.557837
# Epoch 48 / Batch (7/9) / Accuracy 0.2831 / Loss 1.551801
# Epoch 48 / Batch (8/9) / Accuracy 0.2781 / Loss 1.551328
# Epoch 48 / Batch (9/9) / Accuracy 0.2544 / Loss 1.557306
# Epoch 48 complete, 2.469672203063965 seconds elapsed
#
# Epoch 49 starting..
# Epoch 49 / Batch (1/9) / Accuracy 0.2812 / Loss 1.550558
# Epoch 49 / Batch (2/9) / Accuracy 0.2594 / Loss 1.557093
# Epoch 49 / Batch (3/9) / Accuracy 0.2825 / Loss 1.556650
# Epoch 49 / Batch (4/9) / Accuracy 0.2512 / Loss 1.556737
# Epoch 49 / Batch (5/9) / Accuracy 0.2619 / Loss 1.555242
# Epoch 49 / Batch (6/9) / Accuracy 0.2775 / Loss 1.548419
# Epoch 49 / Batch (7/9) / Accuracy 0.2812 / Loss 1.556054
# Epoch 49 / Batch (8/9) / Accuracy 0.2669 / Loss 1.552233
# Epoch 49 / Batch (9/9) / Accuracy 0.2706 / Loss 1.550971
# Epoch 49 complete, 2.4637341499328613 seconds elapsed
#
# Epoch 50 starting..
# Epoch 50 / Batch (1/9) / Accuracy 0.2569 / Loss 1.559052
# Epoch 50 / Batch (2/9) / Accuracy 0.2650 / Loss 1.555172
# Epoch 50 / Batch (3/9) / Accuracy 0.2625 / Loss 1.554608
# Epoch 50 / Batch (4/9) / Accuracy 0.2656 / Loss 1.555691
# Epoch 50 / Batch (5/9) / Accuracy 0.2587 / Loss 1.549706
# Epoch 50 / Batch (6/9) / Accuracy 0.2619 / Loss 1.566735
# Epoch 50 / Batch (7/9) / Accuracy 0.2675 / Loss 1.552742
# Epoch 50 / Batch (8/9) / Accuracy 0.2663 / Loss 1.553922
# Epoch 50 / Batch (9/9) / Accuracy 0.2706 / Loss 1.558688
# Epoch 50 complete, 2.4205877780914307 seconds elapsed
#
# Epoch 51 starting..
# Epoch 51 / Batch (1/9) / Accuracy 0.2681 / Loss 1.551118
# Epoch 51 / Batch (2/9) / Accuracy 0.2706 / Loss 1.556346
# Epoch 51 / Batch (3/9) / Accuracy 0.2812 / Loss 1.555386
# Epoch 51 / Batch (4/9) / Accuracy 0.2644 / Loss 1.553551
# Epoch 51 / Batch (5/9) / Accuracy 0.2619 / Loss 1.559229
# Epoch 51 / Batch (6/9) / Accuracy 0.2644 / Loss 1.554100
# Epoch 51 / Batch (7/9) / Accuracy 0.2719 / Loss 1.548129
# Epoch 51 / Batch (8/9) / Accuracy 0.2663 / Loss 1.550567
# Epoch 51 / Batch (9/9) / Accuracy 0.2494 / Loss 1.559138
# Epoch 51 complete, 2.451608657836914 seconds elapsed
#
# Epoch 52 starting..
# Epoch 52 / Batch (1/9) / Accuracy 0.2875 / Loss 1.547641
# Epoch 52 / Batch (2/9) / Accuracy 0.2625 / Loss 1.551308
# Epoch 52 / Batch (3/9) / Accuracy 0.2825 / Loss 1.540451
# Epoch 52 / Batch (4/9) / Accuracy 0.2663 / Loss 1.548009
# Epoch 52 / Batch (5/9) / Accuracy 0.2881 / Loss 1.544503
# Epoch 52 / Batch (6/9) / Accuracy 0.2800 / Loss 1.541121
# Epoch 52 / Batch (7/9) / Accuracy 0.2806 / Loss 1.548376
# Epoch 52 / Batch (8/9) / Accuracy 0.2756 / Loss 1.550729
# Epoch 52 / Batch (9/9) / Accuracy 0.2688 / Loss 1.551266
# Epoch 52 complete, 2.386464834213257 seconds elapsed
#
# Epoch 53 starting..
# Epoch 53 / Batch (1/9) / Accuracy 0.2869 / Loss 1.552555
# Epoch 53 / Batch (2/9) / Accuracy 0.2600 / Loss 1.549401
# Epoch 53 / Batch (3/9) / Accuracy 0.2631 / Loss 1.559916
# Epoch 53 / Batch (4/9) / Accuracy 0.2800 / Loss 1.558037
# Epoch 53 / Batch (5/9) / Accuracy 0.2875 / Loss 1.552977
# Epoch 53 / Batch (6/9) / Accuracy 0.2569 / Loss 1.555825
# Epoch 53 / Batch (7/9) / Accuracy 0.2719 / Loss 1.547316
# Epoch 53 / Batch (8/9) / Accuracy 0.2656 / Loss 1.553412
# Epoch 53 / Batch (9/9) / Accuracy 0.2769 / Loss 1.545755
# Epoch 53 complete, 2.417537212371826 seconds elapsed
#
# Epoch 54 starting..
# Epoch 54 / Batch (1/9) / Accuracy 0.2650 / Loss 1.559710
# Epoch 54 / Batch (2/9) / Accuracy 0.2769 / Loss 1.552359
# Epoch 54 / Batch (3/9) / Accuracy 0.2706 / Loss 1.553207
# Epoch 54 / Batch (4/9) / Accuracy 0.2750 / Loss 1.554164
# Epoch 54 / Batch (5/9) / Accuracy 0.2775 / Loss 1.546678
# Epoch 54 / Batch (6/9) / Accuracy 0.2769 / Loss 1.547837
# Epoch 54 / Batch (7/9) / Accuracy 0.2806 / Loss 1.545092
# Epoch 54 / Batch (8/9) / Accuracy 0.2831 / Loss 1.548335
# Epoch 54 / Batch (9/9) / Accuracy 0.2806 / Loss 1.550082
# Epoch 54 complete, 2.405033588409424 seconds elapsed
#
# Epoch 55 starting..
# Epoch 55 / Batch (1/9) / Accuracy 0.2819 / Loss 1.546648
# Epoch 55 / Batch (2/9) / Accuracy 0.2650 / Loss 1.550743
# Epoch 55 / Batch (3/9) / Accuracy 0.2750 / Loss 1.547646
# Epoch 55 / Batch (4/9) / Accuracy 0.2631 / Loss 1.553170
# Epoch 55 / Batch (5/9) / Accuracy 0.2831 / Loss 1.555918
# Epoch 55 / Batch (6/9) / Accuracy 0.2831 / Loss 1.548519
# Epoch 55 / Batch (7/9) / Accuracy 0.2575 / Loss 1.560338
# Epoch 55 / Batch (8/9) / Accuracy 0.2719 / Loss 1.546361
# Epoch 55 / Batch (9/9) / Accuracy 0.2837 / Loss 1.547400
# Epoch 55 complete, 2.3946762084960938 seconds elapsed
#
# Epoch 56 starting..
# Epoch 56 / Batch (1/9) / Accuracy 0.2544 / Loss 1.550360
# Epoch 56 / Batch (2/9) / Accuracy 0.2713 / Loss 1.549115
# Epoch 56 / Batch (3/9) / Accuracy 0.2800 / Loss 1.553228
# Epoch 56 / Batch (4/9) / Accuracy 0.2625 / Loss 1.554597
# Epoch 56 / Batch (5/9) / Accuracy 0.2650 / Loss 1.560858
# Epoch 56 / Batch (6/9) / Accuracy 0.2625 / Loss 1.548972
# Epoch 56 / Batch (7/9) / Accuracy 0.2650 / Loss 1.561017
# Epoch 56 / Batch (8/9) / Accuracy 0.2837 / Loss 1.544255
# Epoch 56 / Batch (9/9) / Accuracy 0.2575 / Loss 1.552925
# Epoch 56 complete, 2.393155574798584 seconds elapsed
#
# Epoch 57 starting..
# Epoch 57 / Batch (1/9) / Accuracy 0.2725 / Loss 1.551424
# Epoch 57 / Batch (2/9) / Accuracy 0.2850 / Loss 1.545435
# Epoch 57 / Batch (3/9) / Accuracy 0.2738 / Loss 1.544160
# Epoch 57 / Batch (4/9) / Accuracy 0.2806 / Loss 1.547672
# Epoch 57 / Batch (5/9) / Accuracy 0.2850 / Loss 1.542778
# Epoch 57 / Batch (6/9) / Accuracy 0.2719 / Loss 1.546834
# Epoch 57 / Batch (7/9) / Accuracy 0.2744 / Loss 1.547750
# Epoch 57 / Batch (8/9) / Accuracy 0.2819 / Loss 1.551311
# Epoch 57 / Batch (9/9) / Accuracy 0.2856 / Loss 1.544817
# Epoch 57 complete, 2.4271163940429688 seconds elapsed
#
# Epoch 58 starting..
# Epoch 58 / Batch (1/9) / Accuracy 0.2731 / Loss 1.552220
# Epoch 58 / Batch (2/9) / Accuracy 0.2769 / Loss 1.546912
# Epoch 58 / Batch (3/9) / Accuracy 0.2713 / Loss 1.548347
# Epoch 58 / Batch (4/9) / Accuracy 0.2781 / Loss 1.549758
# Epoch 58 / Batch (5/9) / Accuracy 0.2781 / Loss 1.545287
# Epoch 58 / Batch (6/9) / Accuracy 0.2800 / Loss 1.542366
# Epoch 58 / Batch (7/9) / Accuracy 0.2825 / Loss 1.544468
# Epoch 58 / Batch (8/9) / Accuracy 0.2625 / Loss 1.545408
# Epoch 58 / Batch (9/9) / Accuracy 0.2669 / Loss 1.545451
# Epoch 58 complete, 2.4406075477600098 seconds elapsed
#
# Epoch 59 starting..
# Epoch 59 / Batch (1/9) / Accuracy 0.2775 / Loss 1.543946
# Epoch 59 / Batch (2/9) / Accuracy 0.2756 / Loss 1.543163
# Epoch 59 / Batch (3/9) / Accuracy 0.2706 / Loss 1.543126
# Epoch 59 / Batch (4/9) / Accuracy 0.2856 / Loss 1.538749
# Epoch 59 / Batch (5/9) / Accuracy 0.2806 / Loss 1.548090
# Epoch 59 / Batch (6/9) / Accuracy 0.2806 / Loss 1.542846
# Epoch 59 / Batch (7/9) / Accuracy 0.2575 / Loss 1.557814
# Epoch 59 / Batch (8/9) / Accuracy 0.2713 / Loss 1.548286
# Epoch 59 / Batch (9/9) / Accuracy 0.2706 / Loss 1.561662
# Epoch 59 complete, 2.428757429122925 seconds elapsed
#
# Epoch 60 starting..
# Epoch 60 / Batch (1/9) / Accuracy 0.2794 / Loss 1.545783
# Epoch 60 / Batch (2/9) / Accuracy 0.2781 / Loss 1.548304
# Epoch 60 / Batch (3/9) / Accuracy 0.2756 / Loss 1.550526
# Epoch 60 / Batch (4/9) / Accuracy 0.2650 / Loss 1.547997
# Epoch 60 / Batch (5/9) / Accuracy 0.2581 / Loss 1.548144
# Epoch 60 / Batch (6/9) / Accuracy 0.2819 / Loss 1.552434
# Epoch 60 / Batch (7/9) / Accuracy 0.2675 / Loss 1.555931
# Epoch 60 / Batch (8/9) / Accuracy 0.2831 / Loss 1.549333
# Epoch 60 / Batch (9/9) / Accuracy 0.2644 / Loss 1.556070
# Epoch 60 complete, 2.411863088607788 seconds elapsed
#
# Epoch 61 starting..
# Epoch 61 / Batch (1/9) / Accuracy 0.2881 / Loss 1.546228
# Epoch 61 / Batch (2/9) / Accuracy 0.2856 / Loss 1.548531
# Epoch 61 / Batch (3/9) / Accuracy 0.2713 / Loss 1.547379
# Epoch 61 / Batch (4/9) / Accuracy 0.2694 / Loss 1.546503
# Epoch 61 / Batch (5/9) / Accuracy 0.2738 / Loss 1.551298
# Epoch 61 / Batch (6/9) / Accuracy 0.2681 / Loss 1.549366
# Epoch 61 / Batch (7/9) / Accuracy 0.2606 / Loss 1.550125
# Epoch 61 / Batch (8/9) / Accuracy 0.2800 / Loss 1.557209
# Epoch 61 / Batch (9/9) / Accuracy 0.2663 / Loss 1.549694
# Epoch 61 complete, 2.435471773147583 seconds elapsed
#
# Epoch 62 starting..
# Epoch 62 / Batch (1/9) / Accuracy 0.2575 / Loss 1.557774
# Epoch 62 / Batch (2/9) / Accuracy 0.2656 / Loss 1.549375
# Epoch 62 / Batch (3/9) / Accuracy 0.2569 / Loss 1.565668
# Epoch 62 / Batch (4/9) / Accuracy 0.2775 / Loss 1.545808
# Epoch 62 / Batch (5/9) / Accuracy 0.2794 / Loss 1.550674
# Epoch 62 / Batch (6/9) / Accuracy 0.2775 / Loss 1.544690
# Epoch 62 / Batch (7/9) / Accuracy 0.2844 / Loss 1.552297
# Epoch 62 / Batch (8/9) / Accuracy 0.2781 / Loss 1.542204
# Epoch 62 / Batch (9/9) / Accuracy 0.2619 / Loss 1.554130
# Epoch 62 complete, 2.4280412197113037 seconds elapsed
#
# Epoch 63 starting..
# Epoch 63 / Batch (1/9) / Accuracy 0.2675 / Loss 1.548279
# Epoch 63 / Batch (2/9) / Accuracy 0.2837 / Loss 1.547766
# Epoch 63 / Batch (3/9) / Accuracy 0.2725 / Loss 1.543553
# Epoch 63 / Batch (4/9) / Accuracy 0.2862 / Loss 1.539871
# Epoch 63 / Batch (5/9) / Accuracy 0.2850 / Loss 1.545108
# Epoch 63 / Batch (6/9) / Accuracy 0.2806 / Loss 1.549235
# Epoch 63 / Batch (7/9) / Accuracy 0.2750 / Loss 1.547339
# Epoch 63 / Batch (8/9) / Accuracy 0.2625 / Loss 1.554181
# Epoch 63 / Batch (9/9) / Accuracy 0.2587 / Loss 1.554495
# Epoch 63 complete, 2.4363644123077393 seconds elapsed
#
# Epoch 64 starting..
# Epoch 64 / Batch (1/9) / Accuracy 0.2775 / Loss 1.547604
# Epoch 64 / Batch (2/9) / Accuracy 0.2844 / Loss 1.543346
# Epoch 64 / Batch (3/9) / Accuracy 0.2806 / Loss 1.542767
# Epoch 64 / Batch (4/9) / Accuracy 0.2862 / Loss 1.547005
# Epoch 64 / Batch (5/9) / Accuracy 0.2794 / Loss 1.542352
# Epoch 64 / Batch (6/9) / Accuracy 0.2675 / Loss 1.546346
# Epoch 64 / Batch (7/9) / Accuracy 0.2738 / Loss 1.541882
# Epoch 64 / Batch (8/9) / Accuracy 0.2713 / Loss 1.545709
# Epoch 64 / Batch (9/9) / Accuracy 0.2631 / Loss 1.548424
# Epoch 64 complete, 2.4282424449920654 seconds elapsed
#
# Epoch 65 starting..
# Epoch 65 / Batch (1/9) / Accuracy 0.2850 / Loss 1.542032
# Epoch 65 / Batch (2/9) / Accuracy 0.2706 / Loss 1.552029
# Epoch 65 / Batch (3/9) / Accuracy 0.2744 / Loss 1.547957
# Epoch 65 / Batch (4/9) / Accuracy 0.2700 / Loss 1.545112
# Epoch 65 / Batch (5/9) / Accuracy 0.2681 / Loss 1.563139
# Epoch 65 / Batch (6/9) / Accuracy 0.2719 / Loss 1.559119
# Epoch 65 / Batch (7/9) / Accuracy 0.2581 / Loss 1.556547
# Epoch 65 / Batch (8/9) / Accuracy 0.2525 / Loss 1.568954
# Epoch 65 / Batch (9/9) / Accuracy 0.2675 / Loss 1.545436
# Epoch 65 complete, 2.4391403198242188 seconds elapsed
#
# Epoch 66 starting..
# Epoch 66 / Batch (1/9) / Accuracy 0.2706 / Loss 1.559106
# Epoch 66 / Batch (2/9) / Accuracy 0.2744 / Loss 1.548262
# Epoch 66 / Batch (3/9) / Accuracy 0.2756 / Loss 1.554022
# Epoch 66 / Batch (4/9) / Accuracy 0.2631 / Loss 1.549632
# Epoch 66 / Batch (5/9) / Accuracy 0.2713 / Loss 1.548148
# Epoch 66 / Batch (6/9) / Accuracy 0.2738 / Loss 1.550042
# Epoch 66 / Batch (7/9) / Accuracy 0.2594 / Loss 1.547118
# Epoch 66 / Batch (8/9) / Accuracy 0.2619 / Loss 1.552644
# Epoch 66 / Batch (9/9) / Accuracy 0.2725 / Loss 1.547594
# Epoch 66 complete, 2.45627760887146 seconds elapsed
#
# Epoch 67 starting..
# Epoch 67 / Batch (1/9) / Accuracy 0.2675 / Loss 1.557953
# Epoch 67 / Batch (2/9) / Accuracy 0.2625 / Loss 1.571160
# Epoch 67 / Batch (3/9) / Accuracy 0.2606 / Loss 1.557198
# Epoch 67 / Batch (4/9) / Accuracy 0.2537 / Loss 1.572301
# Epoch 67 / Batch (5/9) / Accuracy 0.2544 / Loss 1.559848
# Epoch 67 / Batch (6/9) / Accuracy 0.2581 / Loss 1.560481
# Epoch 67 / Batch (7/9) / Accuracy 0.2688 / Loss 1.564978
# Epoch 67 / Batch (8/9) / Accuracy 0.2788 / Loss 1.548306
# Epoch 67 / Batch (9/9) / Accuracy 0.2669 / Loss 1.553594
# Epoch 67 complete, 2.3967444896698 seconds elapsed
#
# Epoch 68 starting..
# Epoch 68 / Batch (1/9) / Accuracy 0.2725 / Loss 1.549978
# Epoch 68 / Batch (2/9) / Accuracy 0.2637 / Loss 1.551775
# Epoch 68 / Batch (3/9) / Accuracy 0.2875 / Loss 1.545668
# Epoch 68 / Batch (4/9) / Accuracy 0.2756 / Loss 1.551503
# Epoch 68 / Batch (5/9) / Accuracy 0.2744 / Loss 1.547419
# Epoch 68 / Batch (6/9) / Accuracy 0.2713 / Loss 1.551527
# Epoch 68 / Batch (7/9) / Accuracy 0.2731 / Loss 1.550891
# Epoch 68 / Batch (8/9) / Accuracy 0.2569 / Loss 1.546314
# Epoch 68 / Batch (9/9) / Accuracy 0.2769 / Loss 1.546615
# Epoch 68 complete, 2.3903138637542725 seconds elapsed
#
# Epoch 69 starting..
# Epoch 69 / Batch (1/9) / Accuracy 0.2831 / Loss 1.549046
# Epoch 69 / Batch (2/9) / Accuracy 0.2587 / Loss 1.560523
# Epoch 69 / Batch (3/9) / Accuracy 0.2650 / Loss 1.558382
# Epoch 69 / Batch (4/9) / Accuracy 0.2681 / Loss 1.548223
# Epoch 69 / Batch (5/9) / Accuracy 0.2494 / Loss 1.565096
# Epoch 69 / Batch (6/9) / Accuracy 0.2900 / Loss 1.540822
# Epoch 69 / Batch (7/9) / Accuracy 0.2700 / Loss 1.557922
# Epoch 69 / Batch (8/9) / Accuracy 0.2819 / Loss 1.541190
# Epoch 69 / Batch (9/9) / Accuracy 0.2769 / Loss 1.552133
# Epoch 69 complete, 2.397082805633545 seconds elapsed
#
# Epoch 70 starting..
# Epoch 70 / Batch (1/9) / Accuracy 0.2763 / Loss 1.546903
# Epoch 70 / Batch (2/9) / Accuracy 0.2800 / Loss 1.550348
# Epoch 70 / Batch (3/9) / Accuracy 0.2738 / Loss 1.551099
# Epoch 70 / Batch (4/9) / Accuracy 0.2669 / Loss 1.549698
# Epoch 70 / Batch (5/9) / Accuracy 0.2825 / Loss 1.546887
# Epoch 70 / Batch (6/9) / Accuracy 0.2569 / Loss 1.550138
# Epoch 70 / Batch (7/9) / Accuracy 0.2656 / Loss 1.555772
# Epoch 70 / Batch (8/9) / Accuracy 0.2681 / Loss 1.550334
# Epoch 70 / Batch (9/9) / Accuracy 0.2844 / Loss 1.542898
# Epoch 70 complete, 2.4083259105682373 seconds elapsed
#
# Epoch 71 starting..
# Epoch 71 / Batch (1/9) / Accuracy 0.2756 / Loss 1.546273
# Epoch 71 / Batch (2/9) / Accuracy 0.2862 / Loss 1.544411
# Epoch 71 / Batch (3/9) / Accuracy 0.2681 / Loss 1.553319
# Epoch 71 / Batch (4/9) / Accuracy 0.2675 / Loss 1.561932
# Epoch 71 / Batch (5/9) / Accuracy 0.2725 / Loss 1.555185
# Epoch 71 / Batch (6/9) / Accuracy 0.2644 / Loss 1.549529
# Epoch 71 / Batch (7/9) / Accuracy 0.2537 / Loss 1.552398
# Epoch 71 / Batch (8/9) / Accuracy 0.2725 / Loss 1.546067
# Epoch 71 / Batch (9/9) / Accuracy 0.2675 / Loss 1.553463
# Epoch 71 complete, 2.398111581802368 seconds elapsed
#
# Epoch 72 starting..
# Epoch 72 / Batch (1/9) / Accuracy 0.2744 / Loss 1.547036
# Epoch 72 / Batch (2/9) / Accuracy 0.2713 / Loss 1.550571
# Epoch 72 / Batch (3/9) / Accuracy 0.2862 / Loss 1.545105
# Epoch 72 / Batch (4/9) / Accuracy 0.2656 / Loss 1.552768
# Epoch 72 / Batch (5/9) / Accuracy 0.2763 / Loss 1.550333
# Epoch 72 / Batch (6/9) / Accuracy 0.2713 / Loss 1.546822
# Epoch 72 / Batch (7/9) / Accuracy 0.2700 / Loss 1.544423
# Epoch 72 / Batch (8/9) / Accuracy 0.2750 / Loss 1.545901
# Epoch 72 / Batch (9/9) / Accuracy 0.2881 / Loss 1.543288
# Epoch 72 complete, 2.40364670753479 seconds elapsed
#
# Epoch 73 starting..
# Epoch 73 / Batch (1/9) / Accuracy 0.2775 / Loss 1.545631
# Epoch 73 / Batch (2/9) / Accuracy 0.2681 / Loss 1.551570
# Epoch 73 / Batch (3/9) / Accuracy 0.2763 / Loss 1.566210
# Epoch 73 / Batch (4/9) / Accuracy 0.2744 / Loss 1.545688
# Epoch 73 / Batch (5/9) / Accuracy 0.2862 / Loss 1.555569
# Epoch 73 / Batch (6/9) / Accuracy 0.2700 / Loss 1.551454
# Epoch 73 / Batch (7/9) / Accuracy 0.2794 / Loss 1.547143
# Epoch 73 / Batch (8/9) / Accuracy 0.2825 / Loss 1.547544
# Epoch 73 / Batch (9/9) / Accuracy 0.2781 / Loss 1.546257
# Epoch 73 complete, 2.383070945739746 seconds elapsed
#
# Epoch 74 starting..
# Epoch 74 / Batch (1/9) / Accuracy 0.2819 / Loss 1.548746
# Epoch 74 / Batch (2/9) / Accuracy 0.2550 / Loss 1.557311
# Epoch 74 / Batch (3/9) / Accuracy 0.2756 / Loss 1.539454
# Epoch 74 / Batch (4/9) / Accuracy 0.2681 / Loss 1.542472
# Epoch 74 / Batch (5/9) / Accuracy 0.2837 / Loss 1.545741
# Epoch 74 / Batch (6/9) / Accuracy 0.2881 / Loss 1.543978
# Epoch 74 / Batch (7/9) / Accuracy 0.2738 / Loss 1.542005
# Epoch 74 / Batch (8/9) / Accuracy 0.2681 / Loss 1.548234
# Epoch 74 / Batch (9/9) / Accuracy 0.2644 / Loss 1.561046
# Epoch 74 complete, 2.399223566055298 seconds elapsed
#
# Epoch 75 starting..
# Epoch 75 / Batch (1/9) / Accuracy 0.2744 / Loss 1.547490
# Epoch 75 / Batch (2/9) / Accuracy 0.2663 / Loss 1.549497
# Epoch 75 / Batch (3/9) / Accuracy 0.2637 / Loss 1.553173
# Epoch 75 / Batch (4/9) / Accuracy 0.2719 / Loss 1.549916
# Epoch 75 / Batch (5/9) / Accuracy 0.2750 / Loss 1.554109
# Epoch 75 / Batch (6/9) / Accuracy 0.2800 / Loss 1.549561
# Epoch 75 / Batch (7/9) / Accuracy 0.2731 / Loss 1.548576
# Epoch 75 / Batch (8/9) / Accuracy 0.2663 / Loss 1.548127
# Epoch 75 / Batch (9/9) / Accuracy 0.2763 / Loss 1.546296
# Epoch 75 complete, 2.421445369720459 seconds elapsed
#
# Epoch 76 starting..
# Epoch 76 / Batch (1/9) / Accuracy 0.2637 / Loss 1.554203
# Epoch 76 / Batch (2/9) / Accuracy 0.2781 / Loss 1.548565
# Epoch 76 / Batch (3/9) / Accuracy 0.2569 / Loss 1.556842
# Epoch 76 / Batch (4/9) / Accuracy 0.2869 / Loss 1.547693
# Epoch 76 / Batch (5/9) / Accuracy 0.2637 / Loss 1.553263
# Epoch 76 / Batch (6/9) / Accuracy 0.2837 / Loss 1.546414
# Epoch 76 / Batch (7/9) / Accuracy 0.2688 / Loss 1.548515
# Epoch 76 / Batch (8/9) / Accuracy 0.2713 / Loss 1.544252
# Epoch 76 / Batch (9/9) / Accuracy 0.2800 / Loss 1.547333
# Epoch 76 complete, 2.441779851913452 seconds elapsed
#
# Epoch 77 starting..
# Epoch 77 / Batch (1/9) / Accuracy 0.2956 / Loss 1.541620
# Epoch 77 / Batch (2/9) / Accuracy 0.2594 / Loss 1.550266
# Epoch 77 / Batch (3/9) / Accuracy 0.2756 / Loss 1.546767
# Epoch 77 / Batch (4/9) / Accuracy 0.2744 / Loss 1.545403
# Epoch 77 / Batch (5/9) / Accuracy 0.2812 / Loss 1.548134
# Epoch 77 / Batch (6/9) / Accuracy 0.2669 / Loss 1.549071
# Epoch 77 / Batch (7/9) / Accuracy 0.2625 / Loss 1.544413
# Epoch 77 / Batch (8/9) / Accuracy 0.2781 / Loss 1.547939
# Epoch 77 / Batch (9/9) / Accuracy 0.2719 / Loss 1.544282
# Epoch 77 complete, 2.4184274673461914 seconds elapsed
#
# Epoch 78 starting..
# Epoch 78 / Batch (1/9) / Accuracy 0.2819 / Loss 1.543608
# Epoch 78 / Batch (2/9) / Accuracy 0.2800 / Loss 1.542554
# Epoch 78 / Batch (3/9) / Accuracy 0.2700 / Loss 1.549610
# Epoch 78 / Batch (4/9) / Accuracy 0.2806 / Loss 1.547220
# Epoch 78 / Batch (5/9) / Accuracy 0.2862 / Loss 1.546180
# Epoch 78 / Batch (6/9) / Accuracy 0.2806 / Loss 1.544182
# Epoch 78 / Batch (7/9) / Accuracy 0.2744 / Loss 1.544793
# Epoch 78 / Batch (8/9) / Accuracy 0.2856 / Loss 1.545170
# Epoch 78 / Batch (9/9) / Accuracy 0.2756 / Loss 1.547171
# Epoch 78 complete, 2.4088528156280518 seconds elapsed
#
# Epoch 79 starting..
# Epoch 79 / Batch (1/9) / Accuracy 0.2650 / Loss 1.544837
# Epoch 79 / Batch (2/9) / Accuracy 0.2731 / Loss 1.550332
# Epoch 79 / Batch (3/9) / Accuracy 0.2775 / Loss 1.547694
# Epoch 79 / Batch (4/9) / Accuracy 0.2800 / Loss 1.543420
# Epoch 79 / Batch (5/9) / Accuracy 0.2794 / Loss 1.543312
# Epoch 79 / Batch (6/9) / Accuracy 0.2694 / Loss 1.547446
# Epoch 79 / Batch (7/9) / Accuracy 0.2844 / Loss 1.544560
# Epoch 79 / Batch (8/9) / Accuracy 0.2706 / Loss 1.548822
# Epoch 79 / Batch (9/9) / Accuracy 0.2713 / Loss 1.543042
# Epoch 79 complete, 2.396968364715576 seconds elapsed
#
# Epoch 80 starting..
# Epoch 80 / Batch (1/9) / Accuracy 0.2781 / Loss 1.542974
# Epoch 80 / Batch (2/9) / Accuracy 0.2669 / Loss 1.550828
# Epoch 80 / Batch (3/9) / Accuracy 0.2556 / Loss 1.556383
# Epoch 80 / Batch (4/9) / Accuracy 0.2675 / Loss 1.548544
# Epoch 80 / Batch (5/9) / Accuracy 0.2725 / Loss 1.549496
# Epoch 80 / Batch (6/9) / Accuracy 0.2669 / Loss 1.545346
# Epoch 80 / Batch (7/9) / Accuracy 0.2844 / Loss 1.555082
# Epoch 80 / Batch (8/9) / Accuracy 0.2606 / Loss 1.544589
# Epoch 80 / Batch (9/9) / Accuracy 0.2575 / Loss 1.555768
# Epoch 80 complete, 2.3833420276641846 seconds elapsed
#
# Epoch 81 starting..
# Epoch 81 / Batch (1/9) / Accuracy 0.2750 / Loss 1.548828
# Epoch 81 / Batch (2/9) / Accuracy 0.2881 / Loss 1.547802
# Epoch 81 / Batch (3/9) / Accuracy 0.2900 / Loss 1.547625
# Epoch 81 / Batch (4/9) / Accuracy 0.2819 / Loss 1.549698
# Epoch 81 / Batch (5/9) / Accuracy 0.2719 / Loss 1.546803
# Epoch 81 / Batch (6/9) / Accuracy 0.2506 / Loss 1.560076
# Epoch 81 / Batch (7/9) / Accuracy 0.2750 / Loss 1.543194
# Epoch 81 / Batch (8/9) / Accuracy 0.2781 / Loss 1.550412
# Epoch 81 / Batch (9/9) / Accuracy 0.2625 / Loss 1.548752
# Epoch 81 complete, 2.4237256050109863 seconds elapsed
#
# Epoch 82 starting..
# Epoch 82 / Batch (1/9) / Accuracy 0.2725 / Loss 1.551010
# Epoch 82 / Batch (2/9) / Accuracy 0.2731 / Loss 1.549691
# Epoch 82 / Batch (3/9) / Accuracy 0.2806 / Loss 1.546170
# Epoch 82 / Batch (4/9) / Accuracy 0.2738 / Loss 1.550620
# Epoch 82 / Batch (5/9) / Accuracy 0.2837 / Loss 1.545973
# Epoch 82 / Batch (6/9) / Accuracy 0.2606 / Loss 1.552347
# Epoch 82 / Batch (7/9) / Accuracy 0.2706 / Loss 1.553683
# ...
# Epoch 374 / Batch (4/9) / Accuracy 0.2744 / Loss 1.546512
# Epoch 374 / Batch (5/9) / Accuracy 0.2619 / Loss 1.545036
# Epoch 374 / Batch (6/9) / Accuracy 0.2819 / Loss 1.537736
# Epoch 374 / Batch (7/9) / Accuracy 0.2800 / Loss 1.543665
# Epoch 374 / Batch (8/9) / Accuracy 0.2663 / Loss 1.543658
# Epoch 374 / Batch (9/9) / Accuracy 0.2606 / Loss 1.541767
# Epoch 374 complete, 2.399510622024536 seconds elapsed
#
# Epoch 375 starting..
# Epoch 375 / Batch (1/9) / Accuracy 0.2812 / Loss 1.547355
# Epoch 375 / Batch (2/9) / Accuracy 0.2788 / Loss 1.546198
# Epoch 375 / Batch (3/9) / Accuracy 0.2731 / Loss 1.542398
# Epoch 375 / Batch (4/9) / Accuracy 0.2794 / Loss 1.548569
# Epoch 375 / Batch (5/9) / Accuracy 0.2681 / Loss 1.538146
# Epoch 375 / Batch (6/9) / Accuracy 0.2694 / Loss 1.549711
# Epoch 375 / Batch (7/9) / Accuracy 0.2763 / Loss 1.550518
# Epoch 375 / Batch (8/9) / Accuracy 0.2812 / Loss 1.543819
# Epoch 375 / Batch (9/9) / Accuracy 0.2837 / Loss 1.549544
# Epoch 375 complete, 2.42256760597229 seconds elapsed
#
# Epoch 376 starting..
# Epoch 376 / Batch (1/9) / Accuracy 0.2731 / Loss 1.542846
# Epoch 376 / Batch (2/9) / Accuracy 0.2650 / Loss 1.568419
# Epoch 376 / Batch (3/9) / Accuracy 0.2831 / Loss 1.549415
# Epoch 376 / Batch (4/9) / Accuracy 0.2750 / Loss 1.551461
# Epoch 376 / Batch (5/9) / Accuracy 0.2556 / Loss 1.565176
# Epoch 376 / Batch (6/9) / Accuracy 0.2725 / Loss 1.550247
# Epoch 376 / Batch (7/9) / Accuracy 0.2669 / Loss 1.554083
# Epoch 376 / Batch (8/9) / Accuracy 0.2756 / Loss 1.544666
# Epoch 376 / Batch (9/9) / Accuracy 0.2650 / Loss 1.555417
# Epoch 376 complete, 2.3904054164886475 seconds elapsed
#
# Epoch 377 starting..
# Epoch 377 / Batch (1/9) / Accuracy 0.2831 / Loss 1.546385
# Epoch 377 / Batch (2/9) / Accuracy 0.2769 / Loss 1.551409
# Epoch 377 / Batch (3/9) / Accuracy 0.2537 / Loss 1.550910
# Epoch 377 / Batch (4/9) / Accuracy 0.2637 / Loss 1.547317
# Epoch 377 / Batch (5/9) / Accuracy 0.2800 / Loss 1.546480
# Epoch 377 / Batch (6/9) / Accuracy 0.2656 / Loss 1.548216
# Epoch 377 / Batch (7/9) / Accuracy 0.2763 / Loss 1.544901
# Epoch 377 / Batch (8/9) / Accuracy 0.2650 / Loss 1.545837
# Epoch 377 / Batch (9/9) / Accuracy 0.2869 / Loss 1.547020
# Epoch 377 complete, 2.370255470275879 seconds elapsed
#
# Epoch 378 starting..
# Epoch 378 / Batch (1/9) / Accuracy 0.2631 / Loss 1.545697
# Epoch 378 / Batch (2/9) / Accuracy 0.2706 / Loss 1.558295
# Epoch 378 / Batch (3/9) / Accuracy 0.2656 / Loss 1.558938
# Epoch 378 / Batch (4/9) / Accuracy 0.2612 / Loss 1.546245
# Epoch 378 / Batch (5/9) / Accuracy 0.2806 / Loss 1.540840
# Epoch 378 / Batch (6/9) / Accuracy 0.2881 / Loss 1.545475
# Epoch 378 / Batch (7/9) / Accuracy 0.2631 / Loss 1.552145
# Epoch 378 / Batch (8/9) / Accuracy 0.2700 / Loss 1.549762
# Epoch 378 / Batch (9/9) / Accuracy 0.2675 / Loss 1.550739
# Epoch 378 complete, 2.380685329437256 seconds elapsed
#
# Epoch 379 starting..
# Epoch 379 / Batch (1/9) / Accuracy 0.2738 / Loss 1.549563
# Epoch 379 / Batch (2/9) / Accuracy 0.2769 / Loss 1.549601
# Epoch 379 / Batch (3/9) / Accuracy 0.2731 / Loss 1.551671
# Epoch 379 / Batch (4/9) / Accuracy 0.2756 / Loss 1.551796
# Epoch 379 / Batch (5/9) / Accuracy 0.2669 / Loss 1.551120
# Epoch 379 / Batch (6/9) / Accuracy 0.2706 / Loss 1.546278
# Epoch 379 / Batch (7/9) / Accuracy 0.2725 / Loss 1.549711
# Epoch 379 / Batch (8/9) / Accuracy 0.2844 / Loss 1.545945
# Epoch 379 / Batch (9/9) / Accuracy 0.2738 / Loss 1.547140
# Epoch 379 complete, 2.3758466243743896 seconds elapsed
#
# Epoch 380 starting..
# Epoch 380 / Batch (1/9) / Accuracy 0.2725 / Loss 1.549347
# Epoch 380 / Batch (2/9) / Accuracy 0.2806 / Loss 1.563446
# Epoch 380 / Batch (3/9) / Accuracy 0.2700 / Loss 1.539277
# Epoch 380 / Batch (4/9) / Accuracy 0.2775 / Loss 1.566105
# Epoch 380 / Batch (5/9) / Accuracy 0.2669 / Loss 1.546690
# Epoch 380 / Batch (6/9) / Accuracy 0.2831 / Loss 1.552688
# Epoch 380 / Batch (7/9) / Accuracy 0.2731 / Loss 1.543811
# Epoch 380 / Batch (8/9) / Accuracy 0.2769 / Loss 1.546016
# Epoch 380 / Batch (9/9) / Accuracy 0.2750 / Loss 1.543610
# Epoch 380 complete, 2.397183656692505 seconds elapsed
#
# Epoch 381 starting..
# Epoch 381 / Batch (1/9) / Accuracy 0.2856 / Loss 1.550022
# Epoch 381 / Batch (2/9) / Accuracy 0.2719 / Loss 1.550863
# Epoch 381 / Batch (3/9) / Accuracy 0.2769 / Loss 1.542222
# Epoch 381 / Batch (4/9) / Accuracy 0.2781 / Loss 1.544623
# Epoch 381 / Batch (5/9) / Accuracy 0.2669 / Loss 1.549637
# Epoch 381 / Batch (6/9) / Accuracy 0.2825 / Loss 1.551781
# Epoch 381 / Batch (7/9) / Accuracy 0.2637 / Loss 1.555453
# Epoch 381 / Batch (8/9) / Accuracy 0.2794 / Loss 1.553348
# Epoch 381 / Batch (9/9) / Accuracy 0.2750 / Loss 1.556460
# Epoch 381 complete, 2.440997838973999 seconds elapsed
#
# Epoch 382 starting..
# Epoch 382 / Batch (1/9) / Accuracy 0.2725 / Loss 1.553092
# Epoch 382 / Batch (2/9) / Accuracy 0.2631 / Loss 1.551957
# Epoch 382 / Batch (3/9) / Accuracy 0.2719 / Loss 1.548864
# Epoch 382 / Batch (4/9) / Accuracy 0.2656 / Loss 1.551075
# Epoch 382 / Batch (5/9) / Accuracy 0.2713 / Loss 1.549519
# Epoch 382 / Batch (6/9) / Accuracy 0.2806 / Loss 1.544614
# Epoch 382 / Batch (7/9) / Accuracy 0.2763 / Loss 1.545428
# Epoch 382 / Batch (8/9) / Accuracy 0.2900 / Loss 1.548007
# Epoch 382 / Batch (9/9) / Accuracy 0.2937 / Loss 1.544286
# Epoch 382 complete, 2.408019542694092 seconds elapsed
#
# Epoch 383 starting..
# Epoch 383 / Batch (1/9) / Accuracy 0.2750 / Loss 1.545535
# Epoch 383 / Batch (2/9) / Accuracy 0.2744 / Loss 1.539589
# Epoch 383 / Batch (3/9) / Accuracy 0.2750 / Loss 1.551862
# Epoch 383 / Batch (4/9) / Accuracy 0.2637 / Loss 1.546337
# Epoch 383 / Batch (5/9) / Accuracy 0.2575 / Loss 1.554340
# Epoch 383 / Batch (6/9) / Accuracy 0.2750 / Loss 1.556743
# Epoch 383 / Batch (7/9) / Accuracy 0.2738 / Loss 1.549381
# Epoch 383 / Batch (8/9) / Accuracy 0.2656 / Loss 1.559857
# Epoch 383 / Batch (9/9) / Accuracy 0.2706 / Loss 1.545698
# Epoch 383 complete, 2.4218413829803467 seconds elapsed
#
# Epoch 384 starting..
# Epoch 384 / Batch (1/9) / Accuracy 0.2825 / Loss 1.552819
# Epoch 384 / Batch (2/9) / Accuracy 0.2763 / Loss 1.544878
# Epoch 384 / Batch (3/9) / Accuracy 0.2700 / Loss 1.552026
# Epoch 384 / Batch (4/9) / Accuracy 0.2719 / Loss 1.548725
# Epoch 384 / Batch (5/9) / Accuracy 0.2756 / Loss 1.549255
# Epoch 384 / Batch (6/9) / Accuracy 0.2650 / Loss 1.547710
# Epoch 384 / Batch (7/9) / Accuracy 0.2719 / Loss 1.548179
# Epoch 384 / Batch (8/9) / Accuracy 0.2650 / Loss 1.554635
# Epoch 384 / Batch (9/9) / Accuracy 0.2800 / Loss 1.543344
# Epoch 384 complete, 2.3880343437194824 seconds elapsed
#
# Epoch 385 starting..
# Epoch 385 / Batch (1/9) / Accuracy 0.2656 / Loss 1.551176
# Epoch 385 / Batch (2/9) / Accuracy 0.2862 / Loss 1.541911
# Epoch 385 / Batch (3/9) / Accuracy 0.2594 / Loss 1.549685
# Epoch 385 / Batch (4/9) / Accuracy 0.2719 / Loss 1.543707
# Epoch 385 / Batch (5/9) / Accuracy 0.2769 / Loss 1.551045
# Epoch 385 / Batch (6/9) / Accuracy 0.2800 / Loss 1.545511
# Epoch 385 / Batch (7/9) / Accuracy 0.2681 / Loss 1.539736
# Epoch 385 / Batch (8/9) / Accuracy 0.2713 / Loss 1.545831
# Epoch 385 / Batch (9/9) / Accuracy 0.2788 / Loss 1.543611
# Epoch 385 complete, 2.3727610111236572 seconds elapsed
#
# Epoch 386 starting..
# Epoch 386 / Batch (1/9) / Accuracy 0.2887 / Loss 1.540999
# Epoch 386 / Batch (2/9) / Accuracy 0.2694 / Loss 1.541427
# Epoch 386 / Batch (3/9) / Accuracy 0.2744 / Loss 1.545006
# Epoch 386 / Batch (4/9) / Accuracy 0.2694 / Loss 1.550090
# Epoch 386 / Batch (5/9) / Accuracy 0.2706 / Loss 1.538081
# Epoch 386 / Batch (6/9) / Accuracy 0.2806 / Loss 1.539861
# Epoch 386 / Batch (7/9) / Accuracy 0.2781 / Loss 1.538451
# Epoch 386 / Batch (8/9) / Accuracy 0.2725 / Loss 1.539740
# Epoch 386 / Batch (9/9) / Accuracy 0.2700 / Loss 1.551808
# Epoch 386 complete, 2.446913480758667 seconds elapsed
#
# Epoch 387 starting..
# Epoch 387 / Batch (1/9) / Accuracy 0.2644 / Loss 1.550451
# Epoch 387 / Batch (2/9) / Accuracy 0.2744 / Loss 1.541121
# Epoch 387 / Batch (3/9) / Accuracy 0.2806 / Loss 1.547227
# Epoch 387 / Batch (4/9) / Accuracy 0.2775 / Loss 1.542839
# Epoch 387 / Batch (5/9) / Accuracy 0.2763 / Loss 1.538645
# Epoch 387 / Batch (6/9) / Accuracy 0.2800 / Loss 1.544991
# Epoch 387 / Batch (7/9) / Accuracy 0.2800 / Loss 1.547005
# Epoch 387 / Batch (8/9) / Accuracy 0.2875 / Loss 1.538124
# Epoch 387 / Batch (9/9) / Accuracy 0.2650 / Loss 1.546968
# Epoch 387 complete, 2.427318572998047 seconds elapsed
#
# Epoch 388 starting..
# Epoch 388 / Batch (1/9) / Accuracy 0.2656 / Loss 1.540562
# Epoch 388 / Batch (2/9) / Accuracy 0.2631 / Loss 1.550983
# Epoch 388 / Batch (3/9) / Accuracy 0.2781 / Loss 1.547493
# Epoch 388 / Batch (4/9) / Accuracy 0.2763 / Loss 1.547268
# Epoch 388 / Batch (5/9) / Accuracy 0.2869 / Loss 1.543782
# Epoch 388 / Batch (6/9) / Accuracy 0.2694 / Loss 1.544442
# Epoch 388 / Batch (7/9) / Accuracy 0.2700 / Loss 1.551144
# Epoch 388 / Batch (8/9) / Accuracy 0.2763 / Loss 1.537947
# Epoch 388 / Batch (9/9) / Accuracy 0.2694 / Loss 1.551670
# Epoch 388 complete, 2.455878496170044 seconds elapsed
#
# Epoch 389 starting..
# Epoch 389 / Batch (1/9) / Accuracy 0.2744 / Loss 1.547310
# Epoch 389 / Batch (2/9) / Accuracy 0.2837 / Loss 1.548827
# Epoch 389 / Batch (3/9) / Accuracy 0.2919 / Loss 1.544711
# Epoch 389 / Batch (4/9) / Accuracy 0.2819 / Loss 1.542704
# Epoch 389 / Batch (5/9) / Accuracy 0.2731 / Loss 1.548911
# Epoch 389 / Batch (6/9) / Accuracy 0.2700 / Loss 1.546759
# Epoch 389 / Batch (7/9) / Accuracy 0.2744 / Loss 1.544963
# Epoch 389 / Batch (8/9) / Accuracy 0.2769 / Loss 1.542113
# Epoch 389 / Batch (9/9) / Accuracy 0.2825 / Loss 1.541809
# Epoch 389 complete, 2.4175779819488525 seconds elapsed
#
# Epoch 390 starting..
# Epoch 390 / Batch (1/9) / Accuracy 0.2650 / Loss 1.544803
# Epoch 390 / Batch (2/9) / Accuracy 0.2694 / Loss 1.543236
# Epoch 390 / Batch (3/9) / Accuracy 0.2756 / Loss 1.543130
# Epoch 390 / Batch (4/9) / Accuracy 0.2763 / Loss 1.542305
# Epoch 390 / Batch (5/9) / Accuracy 0.2744 / Loss 1.544546
# Epoch 390 / Batch (6/9) / Accuracy 0.2700 / Loss 1.540661
# Epoch 390 / Batch (7/9) / Accuracy 0.2875 / Loss 1.539562
# Epoch 390 / Batch (8/9) / Accuracy 0.2750 / Loss 1.542583
# Epoch 390 / Batch (9/9) / Accuracy 0.2750 / Loss 1.537296
# Epoch 390 complete, 2.4632246494293213 seconds elapsed
#
# Epoch 391 starting..
# Epoch 391 / Batch (1/9) / Accuracy 0.2650 / Loss 1.549225
# Epoch 391 / Batch (2/9) / Accuracy 0.2575 / Loss 1.554931
# Epoch 391 / Batch (3/9) / Accuracy 0.2663 / Loss 1.556465
# Epoch 391 / Batch (4/9) / Accuracy 0.2756 / Loss 1.544376
# Epoch 391 / Batch (5/9) / Accuracy 0.2800 / Loss 1.542126
# Epoch 391 / Batch (6/9) / Accuracy 0.2962 / Loss 1.540935
# Epoch 391 / Batch (7/9) / Accuracy 0.2731 / Loss 1.546904
# Epoch 391 / Batch (8/9) / Accuracy 0.2781 / Loss 1.542765
# Epoch 391 / Batch (9/9) / Accuracy 0.2788 / Loss 1.544444
# Epoch 391 complete, 2.4278218746185303 seconds elapsed
#
# Epoch 392 starting..
# Epoch 392 / Batch (1/9) / Accuracy 0.2669 / Loss 1.537851
# Epoch 392 / Batch (2/9) / Accuracy 0.2819 / Loss 1.542676
# Epoch 392 / Batch (3/9) / Accuracy 0.2875 / Loss 1.541878
# Epoch 392 / Batch (4/9) / Accuracy 0.2788 / Loss 1.541901
# Epoch 392 / Batch (5/9) / Accuracy 0.2575 / Loss 1.544338
# Epoch 392 / Batch (6/9) / Accuracy 0.2663 / Loss 1.547960
# Epoch 392 / Batch (7/9) / Accuracy 0.2625 / Loss 1.557801
# Epoch 392 / Batch (8/9) / Accuracy 0.2688 / Loss 1.547370
# Epoch 392 / Batch (9/9) / Accuracy 0.2887 / Loss 1.541136
# Epoch 392 complete, 2.374099016189575 seconds elapsed
#
# Epoch 393 starting..
# Epoch 393 / Batch (1/9) / Accuracy 0.2812 / Loss 1.538744
# Epoch 393 / Batch (2/9) / Accuracy 0.2594 / Loss 1.548277
# Epoch 393 / Batch (3/9) / Accuracy 0.2600 / Loss 1.543391
# Epoch 393 / Batch (4/9) / Accuracy 0.2725 / Loss 1.545152
# Epoch 393 / Batch (5/9) / Accuracy 0.2788 / Loss 1.540644
# Epoch 393 / Batch (6/9) / Accuracy 0.2825 / Loss 1.541192
# Epoch 393 / Batch (7/9) / Accuracy 0.2594 / Loss 1.546273
# Epoch 393 / Batch (8/9) / Accuracy 0.2769 / Loss 1.542401
# Epoch 393 / Batch (9/9) / Accuracy 0.2631 / Loss 1.552641
# Epoch 393 complete, 2.394667863845825 seconds elapsed
#
# Epoch 394 starting..
# Epoch 394 / Batch (1/9) / Accuracy 0.2781 / Loss 1.552236
# Epoch 394 / Batch (2/9) / Accuracy 0.2700 / Loss 1.549518
# Epoch 394 / Batch (3/9) / Accuracy 0.2694 / Loss 1.554391
# Epoch 394 / Batch (4/9) / Accuracy 0.2587 / Loss 1.553179
# Epoch 394 / Batch (5/9) / Accuracy 0.2631 / Loss 1.547265
# Epoch 394 / Batch (6/9) / Accuracy 0.2794 / Loss 1.549832
# Epoch 394 / Batch (7/9) / Accuracy 0.2562 / Loss 1.547642
# Epoch 394 / Batch (8/9) / Accuracy 0.2781 / Loss 1.546767
# Epoch 394 / Batch (9/9) / Accuracy 0.2831 / Loss 1.542176
# Epoch 394 complete, 2.355509042739868 seconds elapsed
#
# Epoch 395 starting..
# Epoch 395 / Batch (1/9) / Accuracy 0.2725 / Loss 1.554664
# Epoch 395 / Batch (2/9) / Accuracy 0.2656 / Loss 1.545709
# Epoch 395 / Batch (3/9) / Accuracy 0.2756 / Loss 1.547844
# Epoch 395 / Batch (4/9) / Accuracy 0.2788 / Loss 1.541337
# Epoch 395 / Batch (5/9) / Accuracy 0.2862 / Loss 1.537714
# Epoch 395 / Batch (6/9) / Accuracy 0.2756 / Loss 1.540677
# Epoch 395 / Batch (7/9) / Accuracy 0.2587 / Loss 1.557738
# Epoch 395 / Batch (8/9) / Accuracy 0.2650 / Loss 1.562698
# Epoch 395 / Batch (9/9) / Accuracy 0.2794 / Loss 1.548872
# Epoch 395 complete, 2.3823401927948 seconds elapsed
#
# Epoch 396 starting..
# Epoch 396 / Batch (1/9) / Accuracy 0.2719 / Loss 1.570287
# Epoch 396 / Batch (2/9) / Accuracy 0.2637 / Loss 1.547258
# Epoch 396 / Batch (3/9) / Accuracy 0.2744 / Loss 1.553148
# Epoch 396 / Batch (4/9) / Accuracy 0.2600 / Loss 1.553725
# Epoch 396 / Batch (5/9) / Accuracy 0.2675 / Loss 1.551448
# Epoch 396 / Batch (6/9) / Accuracy 0.2631 / Loss 1.555408
# Epoch 396 / Batch (7/9) / Accuracy 0.2763 / Loss 1.549695
# Epoch 396 / Batch (8/9) / Accuracy 0.2644 / Loss 1.554155
# Epoch 396 / Batch (9/9) / Accuracy 0.2731 / Loss 1.546253
# Epoch 396 complete, 2.445558786392212 seconds elapsed
#
# Epoch 397 starting..
# Epoch 397 / Batch (1/9) / Accuracy 0.2769 / Loss 1.550563
# Epoch 397 / Batch (2/9) / Accuracy 0.2756 / Loss 1.546057
# Epoch 397 / Batch (3/9) / Accuracy 0.2806 / Loss 1.544391
# Epoch 397 / Batch (4/9) / Accuracy 0.2700 / Loss 1.544463
# Epoch 397 / Batch (5/9) / Accuracy 0.2669 / Loss 1.548909
# Epoch 397 / Batch (6/9) / Accuracy 0.2825 / Loss 1.560169
# Epoch 397 / Batch (7/9) / Accuracy 0.2812 / Loss 1.545525
# Epoch 397 / Batch (8/9) / Accuracy 0.2706 / Loss 1.561489
# Epoch 397 / Batch (9/9) / Accuracy 0.2663 / Loss 1.546069
# Epoch 397 complete, 2.4287548065185547 seconds elapsed
#
# Epoch 398 starting..
# Epoch 398 / Batch (1/9) / Accuracy 0.2631 / Loss 1.550405
# Epoch 398 / Batch (2/9) / Accuracy 0.2681 / Loss 1.546342
# Epoch 398 / Batch (3/9) / Accuracy 0.2688 / Loss 1.551159
# Epoch 398 / Batch (4/9) / Accuracy 0.2819 / Loss 1.545580
# Epoch 398 / Batch (5/9) / Accuracy 0.2619 / Loss 1.549197
# Epoch 398 / Batch (6/9) / Accuracy 0.2725 / Loss 1.548365
# Epoch 398 / Batch (7/9) / Accuracy 0.2781 / Loss 1.546925
# Epoch 398 / Batch (8/9) / Accuracy 0.2725 / Loss 1.545061
# Epoch 398 / Batch (9/9) / Accuracy 0.2794 / Loss 1.546861
# Epoch 398 complete, 2.4278411865234375 seconds elapsed
#
# Epoch 399 starting..
# Epoch 399 / Batch (1/9) / Accuracy 0.2725 / Loss 1.541735
# Epoch 399 / Batch (2/9) / Accuracy 0.2650 / Loss 1.545708
# Epoch 399 / Batch (3/9) / Accuracy 0.2769 / Loss 1.541266
# Epoch 399 / Batch (4/9) / Accuracy 0.2719 / Loss 1.542176
# Epoch 399 / Batch (5/9) / Accuracy 0.2688 / Loss 1.537882
# Epoch 399 / Batch (6/9) / Accuracy 0.2731 / Loss 1.545658
# Epoch 399 / Batch (7/9) / Accuracy 0.2800 / Loss 1.539491
# Epoch 399 / Batch (8/9) / Accuracy 0.2800 / Loss 1.546785
# Epoch 399 / Batch (9/9) / Accuracy 0.2837 / Loss 1.539063
# Epoch 399 complete, 2.4140377044677734 seconds elapsed
#
# Epoch 400 starting..
# Epoch 400 / Batch (1/9) / Accuracy 0.2769 / Loss 1.539651
# Epoch 400 / Batch (2/9) / Accuracy 0.2694 / Loss 1.539684
# Epoch 400 / Batch (3/9) / Accuracy 0.2869 / Loss 1.537878
# Epoch 400 / Batch (4/9) / Accuracy 0.2844 / Loss 1.539617
# Epoch 400 / Batch (5/9) / Accuracy 0.2969 / Loss 1.540668
# Epoch 400 / Batch (6/9) / Accuracy 0.2650 / Loss 1.545683
# Epoch 400 / Batch (7/9) / Accuracy 0.2794 / Loss 1.539475
# Epoch 400 / Batch (8/9) / Accuracy 0.2856 / Loss 1.535733
# Epoch 400 / Batch (9/9) / Accuracy 0.2706 / Loss 1.538072
# Epoch 400 complete, 2.477424144744873 seconds elapsed

# %%
epochs = range(1,401)
plt.plot(epochs, loss_plot2, 'g', label='Loss')
plt.plot(epochs, accuracy_plot2, 'b', label='Accuracy')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
import csv

a = np.asarray([loss_plot,accuracy_plot,loss_plot2, accuracy_plot2 ])
with open('7th.csv', 'w', newline='') as file:
    mywriter = csv.writer(file, delimiter=',')
    mywriter.writerows(a)

# %%
x = []
y = []
#z = []
  
with open('DATA_main.csv','r') as csvfile:
    lines = csv.reader(csvfile, delimiter=',')
    for row in lines:
        x.append(row[0])
        y.append(float(row[1]))
  
plt.plot(y,x, 'g', label='Accuracy')
#plt.plot(epochs, accuracy_plot2, 'b', label='Accuracy')
plt.title('Accuracy Vs Epochs Plot')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import csv
import matplotlib.pyplot as plt
los = []
epo = []
#z = []
  
with open('DATA_loss.csv','r') as csvfile:
    lines = csv.reader(csvfile, delimiter=',')
    for row in lines:
        los.append(row[0])
        epo.append(float(row[1]))
  
#los, epo = zip(*sorted(zip(los, epo)))
#print(los)
plt.plot(epo,los, 'r', label='Loss')
plt.gca().invert_yaxis()
#plt.plot(epochs, accuracy_plot2, 'b', label='Loss')
plt.title('Loss Vs Epochs Plot')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
